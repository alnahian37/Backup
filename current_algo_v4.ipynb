# %%
import json
import time
import pickle
import kinectpy as kpy
import ast
from kinectpy.k4a._k4atypes import K4A_CALIBRATION_TYPE_DEPTH
import gc




import scipy.io
import numpy as np
import csv
import copy

from scipy.optimize import linear_sum_assignment

import os
import csv

import pickle
import json
import ast

import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from math import inf

import sys
sys.path.insert(1, './../')

from timeit import repeat

import kinectpy as kpy
from kinectpy.k4abt._k4abtTypes import K4ABT_SEGMENT_PAIRS
from kinectpy.k4abt import _k4abt
from kinectpy.k4a import _k4a
from kinectpy.k4a._k4atypes import K4A_CALIBRATION_TYPE_DEPTH, K4A_CALIBRATION_TYPE_COLOR
import logging
from matplotlib import animation
import time
from datetime import datetime
import scipy.io
import time
import socket
from _thread import *



all_indexes=range(60)
#Table
x1=np.linspace(2090,3115,3)
z1=np.linspace(0,740,3)
y1=np.linspace(1570,8850,3)
x1=np.array(x1).reshape(len(x1),1)
y1=np.array(y1).reshape(len(y1),1)
z1=np.array(z1).reshape(len(z1),1)
x,y=np.meshgrid(x1,y1)
z=737*np.ones((len(x1),len(y1)))
z_floor=np.zeros((len(x1),len(y1)))
xx,zz=np.meshgrid(x1,z1)
yy=1570*np.ones((len(x1),len(z1)))
yy2=8850*np.ones((len(x1),len(z1)))
x2=np.linspace(0,4500,3)
z2=np.linspace(0,3000,3)
y2=np.linspace(0,10000,3)
x2=np.array(x2).reshape(len(x2),1)
y2=np.array(y2).reshape(len(y2),1)
z2=np.array(z2).reshape(len(z2),1)
x_floor,y_floor=np.meshgrid(x2,y2)
z_floor=np.zeros((len(x2),len(y2)))
xxx,zzz=np.meshgrid(x2,z2)
yyy=np.zeros((len(x2),len(z2)))
y3,z3=np.meshgrid(y2,z2)
x3=4500*np.ones((len(y2),len(z2)))
y4,z4=np.meshgrid(y2,z2)
x4=np.zeros((len(y2),len(z2)))
y5=10000*np.ones((len(x2),len(z2)))
z2=np.linspace(0,2000,3)
y2=np.linspace(8200,9000,3)
y2=np.array(y2).reshape(len(y2),1)
z2=np.array(z2).reshape(len(z2),1)
y6,z6=np.meshgrid(y2,z2)
x6=np.zeros((len(y2),len(z2)))


def initialize_plots():
    fig = plt.figure(figsize=(10, 10),dpi=200)

    # Create axis
    axes = fig.add_subplot(111, projection='3d')  
    #axes.set_aspect('auto') 
    (x_min, x_max), (y_min, y_max), (z_min, z_max) = ((0, 4500), (0,10400), (0, 3000)) 
   
    #Door
    axes.plot_surface(x6, y6, z6, color='k',alpha=1,edgecolor=None)

    #Wall
    axes.plot_surface(xxx,y5,zzz,alpha=0.5,color='green',edgecolor=None)
    axes.plot_surface(x4,y4,z4,alpha=0.5,color='blue',edgecolor=None)
    axes.plot_surface(x3,y3,z3,alpha=0.5,color='blue',edgecolor=None)
    axes.plot_surface(xxx,yyy,zzz,alpha=0.5,color='green',edgecolor=None)    
    #Table
    axes.plot_surface(xx,yy,zz,color='magenta',alpha=0.5,edgecolor=None)
    axes.plot_surface(xx,yy2,zz,color='magenta',alpha=0.5,edgecolor=None)
    axes.plot_surface(x,y,z,color='magenta',alpha=0.3,edgecolor=None)
    axes.plot_surface(x_floor,y_floor,z_floor,color='blue',alpha=0.2,edgecolor=None)    
    
    axes.set_xlabel('X')
    axes.set_ylabel('Y')
    axes.set_zlabel('Z')
    axes.set_xlim(left=x_min, right=x_max)
    axes.set_ylim(bottom=y_min, top=y_max)
    axes.set_zlim(bottom=z_min, top=z_max)
    axes.axis('off')
    #axes.grid(True)
    #axes.set_axis_off()
    axes.view_init(azim = -115, elev = 35)
    axes.w_zaxis.set_pane_color((0, 1, 0, 0.2))
    axes.get_proj = lambda: np.dot(Axes3D.get_proj(axes), np.diag([0.5, 1, 0.3, 1]))
    plots = {index: axes.plot([0], [0], [0], 'bo-', markersize = 0)[0] for index in all_indexes}

    return fig, axes, plots


#Load the calibrated parameters
p4=scipy.io.loadmat('new_cam4_params_umeyama.mat')['name']
W4=p4[0:3,:]
b4=p4[3:,:]

p3=scipy.io.loadmat('new_cam3_params_umeyama.mat')['name']
W3=p3[0:3,:]
b3=p3[3:,:]

p2=scipy.io.loadmat('new_cam2_params_umeyama.mat')['name']
W2=p2[0:3,:]
b2=p2[3:,:]

p1=scipy.io.loadmat('new_cam1_params_umeyama.mat')['name']
W1=p1[0:3,:]
b1=p1[3:,:]

#Detect Current Frame Activity
def activity_detection(cur_frame):    
    if (sum(cur_frame[:,3])==0):
        #print('No activity detected')
        activ=np.zeros((cur_frame.shape[0],1))
        activ[:]=4 #no activity when no person is present and only zeros are sent here
        return activ
    
    poses=(cur_frame[:,3]>1300).astype(int).reshape(cur_frame.shape[0],1)
    
    activ=copy.deepcopy(poses)    

    ##Activity 1: Random
    if sum(poses)==cur_frame.shape[0]: #All standing        
        activ[:]=1

    ##Activity 2: Table
    elif sum(poses)==0: #All sitting
        activ[:]=2
    
    ##Activity 3: Presentation or Activity 2: Table or Activity 1: Random
    elif sum(poses)>0 and sum(poses)<cur_frame.shape[0]: #Some standing, some sitting
        y_values=np.zeros((cur_frame.shape[0],1))
        x_values=np.zeros((cur_frame.shape[0],1))
        z_values=np.zeros((cur_frame.shape[0],1))
        flag_presentation=0
        
        #if sum(poses)==1:
        if sum(poses)<=0.5*cur_frame.shape[0]: #Most people sitting
            for j in range(cur_frame.shape[0]):
                y_values[j]=cur_frame[j,2]
                x_values[j]=cur_frame[j,1]
                z_values[j]=cur_frame[j,3]

            for j in range(cur_frame.shape[0]):
                if y_values[j]>8650 and x_values[j]>1850 and x_values[j]<4200 and z_values[j]>1300: #Only Presenter is standing
                    flag_presentation=+1
        if flag_presentation>0:
            ######print("PRESENTATION")  ##Activity 3: Presentation
            activ[:]=3
            #flag_presentation=0
        else:
            ######print("Random Standing")
            if (sum(poses)>0.5*cur_frame.shape[0]): #More people standing
                activ[:]=1 #Random
            else:
                activ[:]=2 #Table for majority sitting
    ######print("activ ",activ)
    activ=np.reshape(activ,(cur_frame.shape[0],1))
    #cur_frame=np.hstack((cur_frame,activ))
    return activ

def convert_to_unity(cur_frame):
    unity_data=np.zeros((cur_frame.shape[0],11))

    unity_data[:,0]=cur_frame[:,0]
    unity_data[:,1]=np.round(cur_frame[:,1]/1000,2)-5.1*(cur_frame[:,1]>0)-(cur_frame[:,1]==0)*10  #unity x
    unity_data[:,2]=((cur_frame[:,3]>1300).astype(float)*0.5+1)*(cur_frame[:,3]>0).astype(int) #unity y
    unity_data[:,3]=np.round(cur_frame[:,2]/1000,2)-10.8*(cur_frame[:,2]>0) #unity z
    unity_data[:,4]=cur_frame[:,11]
    unity_data[:,5]=cur_frame[:,13]
    unity_data[:,6]=cur_frame[:,12]
    unity_data[:,7]=cur_frame[:,15].astype(int) #activity
    unity_data[:,8]=(cur_frame[:,3]>1300).astype(int)+1 #pose
    unity_data[:,9]=cur_frame[:,16].astype(int) #sTAtionary
    unity_data[:,10]=0 #glare
    
    return unity_data
def send_to_unity(unity_data):
    data=unity_data[:,1:].reshape(-1)
    send_string='$'.join(map(str, data))
    send_string='Avatar$'+send_string
    return send_string

def get_camera_data(num_bodies4,bodyFrame4,W1,b1):
    cam4s=[]
    for body_id in range(num_bodies4):

        body3d4 = bodyFrame4.get_body3d(body_id, dest_camera = K4A_CALIBRATION_TYPE_DEPTH)
    
        all_joints4=[]
        for joint in body3d4.joints:

            join=joint.get_coordinates()
            #if join[2]>far_threshold:
                #far_flag=1
                
            join=join@W1.T+b1
            join.reshape(3,1)
            con=np.array([joint.confidence_level]).reshape(1,1)
            join_con=np.concatenate((join,con),axis=1)
            all_joints4.append(join_con)
        all_joints4=np.array(all_joints4).reshape(32,4)
        nose_pos=all_joints4[27,0:3]
        tmp=copy.deepcopy(nose_pos)
        nose_pos[1]=tmp[2]
        nose_pos[2]=tmp[1]
        nose_pos[1]=room_length-nose_pos[1]
        
        confidence=np.mean(all_joints4[:,3])
        ear_left=all_joints4[29,0:3]
        tmp=copy.deepcopy(ear_left)
        ear_left[1]=tmp[2]
        ear_left[2]=tmp[1]
        ear_left[1]=room_length-ear_left[1]

        ear_right=all_joints4[31,0:3]
        tmp=copy.deepcopy(ear_right)
        ear_right[1]=tmp[2]
        ear_right[2]=tmp[1]
        ear_right[1]=room_length-ear_right[1]

        
        p1=(ear_left+ear_right)/2
        v=nose_pos-p1 
        p2=500*v / np.linalg.norm(v)+p1 ## 10*front_point-9*back_point
        position_vector=p2-p1
        
        #if nose_pos[1]>z_threshold: # y distance from origin
        
        if 0==0:
            cam4=np.concatenate((np.array([frame]),nose_pos,np.array([confidence]),p1,p2,position_vector))
            cam4s.append(cam4)
            #necks4.append(neck)
        else:
            #far_flag=0
            num_bodies4-=1
        
    if num_bodies4>0:
        cam4s=np.array(cam4s)
        del_idx=np.where(cam4s[:,1]<0)[0]
        print("** index to delete= ",del_idx,"")
    #del_idx=np.where(prev_frame_data[:,-3]==unique_ids[ind])[0]
        cam4s=np.delete(cam4s,del_idx,0)
    return cam4s



#END of Function Declarations above

print("enter 1 for online and 2 for offline")
on_off=int(input())

# Initialize the library, if the library is not found, add the library path as argument
kpy.initialize_libraries(track_body=True)

if on_off==1:

    #Start the devices
    device_config = kpy.default_configuration	
    #device_config.color_resolution = pykinect.K4A_COLOR_RESOLUTION_OF
    device_config.color_resolution=0 
    print("DDD", device_config)
    print("HHH",device_config.color_resolution)
    #device_config.depth_mode = pykinect.K4A_DEPTH_MODE_WFOV_2X2BINNED

    device_config.depth_mode = 2
    device_config.wired_sync_mode=0
    print("GGG",device_config.depth_mode)
    playback4 = kpy.start_device(device_index=0,config=device_config)

    device_config1 = kpy.default_configuration
    device_config1.color_resolution = 0 
    device_config1.depth_mode=2
    device_config1.wired_sync_mode=0
    playback3 = kpy.start_device(device_index=1,config=device_config1)


    ###
    device_config2 = kpy.default_configuration	
    device_config2.color_resolution=0 #2160p
    device_config2.depth_mode = 2
    device_config2.wired_sync_mode=0
    print("GGG",device_config2.depth_mode)
    playback2 = kpy.start_device(device_index=2,config=device_config2)


    device_config3 = kpy.default_configuration
    device_config3.color_resolution = 0 #2160p
    device_config3.depth_mode=2
    device_config3.wired_sync_mode=0
    playback1 = kpy.start_device(device_index=3,config=device_config3)



    playback_config1 = device_config3
    playback_calibration1 = playback1.calibration
    playback_config2 = device_config2
    playback_calibration2 = playback2.calibration
    playback_config3 = device_config1 #playback3.get_record_configuration()
    playback_calibration3 = playback3.calibration
    playback_config4 = device_config #playback4.get_record_configuration()
    playback_calibration4 = playback4.calibration

elif on_off==2:
    video1_filename=r"D:\Kinect Tools\Nahian\Code Backup Mar 29\All_code_f\Neo kinect calibration\New Calibration\video jan19\jan4.mkv"
    video2_filename=r"D:\Kinect Tools\Nahian\Code Backup Mar 29\All_code_f\Neo kinect calibration\New Calibration\video jan19\jan3.mkv"
    video3_filename=r"D:\Kinect Tools\Nahian\Code Backup Mar 29\All_code_f\Neo kinect calibration\New Calibration\video jan19\jan2.mkv"
    video4_filename=r"D:\Kinect Tools\Nahian\Code Backup Mar 29\All_code_f\Neo kinect calibration\New Calibration\video jan19\jan1.mkv"

    #video1_filename=r"D:\Video Data\Video Feb 2 Backup\videos_1\output1_1.mkv"
    #video2_filename=r"D:\Video Data\Video Feb 2 Backup\videos_1\output1_2.mkv"
    #video3_filename=r"D:\Video Data\Video Feb 2 Backup\videos_1\output1_3.mkv"
    #video4_filename=r"D:\Video Data\Video Feb 2 Backup\videos_1\output1_4.mkv"


    playback1 = kpy.start_playback(video1_filename)
    playback2 = kpy.start_playback(video2_filename)
    playback3 = kpy.start_playback(video3_filename)
    playback4 = kpy.start_playback(video4_filename)

    playback_config1 = playback1.get_record_configuration()
    playback_calibration1 = playback1.get_calibration()
    playback_config2 = playback2.get_record_configuration()
    playback_calibration2 = playback2.get_calibration()
    playback_config3 = playback3.get_record_configuration()
    playback_calibration3 = playback3.get_calibration()
    playback_config4 = playback4.get_record_configuration()
    playback_calibration4 = playback4.get_calibration()




bodyTracker1 = kpy.start_body_tracker(calibration=playback_calibration1)
bodyTracker2 = kpy.start_body_tracker(calibration=playback_calibration2)
bodyTracker3 = kpy.start_body_tracker(calibration=playback3.calibration)
bodyTracker4 = kpy.start_body_tracker(calibration=playback4.calibration)



fig, axes, plots = initialize_plots()    

plt.ion()

def showing_plot(plot_data):
    poin1s=[]
    poin2s=[]
    poin3s=[]
    poin4s=[]
    for i in range(plot_data.shape[0]):
        x1=plot_data[i][5]
        y1=plot_data[i][6]
        z1=plot_data[i][7]
        x2=plot_data[i][8]
        y2=plot_data[i][9]
        z2=plot_data[i][10]

        poin1=np.array([x1,y1,z1])
        poin2=np.array([x2,y2,z2])
        poin3=np.array([x1,y1,0])
        poin1s.append(poin1)
        poin2s.append(poin2)
        poin3s.append(poin3)
        poin4s.append(plot_data[i][16])
    for l in range(len(all_indexes)):
        plots[l].set_xdata(np.asarray(0))
        plots[l].set_ydata(np.asarray(0))
        plots[l].set_3d_properties(np.asarray(0))
    
    poin1s=np.array(poin1s)
    poin2s=np.array(poin2s)
    poin3s=np.array(poin3s)
    poin4s=np.array(poin4s)
    for i in range(poin1s.shape[0]):
        if i==0:
            color = ((1, 0, 0))
        elif i==1:
            color = ((0, 1, 0))
        elif i==2:
            color = ((0, 0, 1))
        elif i==3:
            color = ((1, 1, 0))
        elif i==4:
            color = ((1, 0, 1))
        elif i==5:
            color = ((0, 1, 1))
        elif i==6:
            color = ((0.75, 0.75, 0.75))
        elif i==7:
            color = ((0.5, 0, 0))
        elif i==8:
            color = ((0, 0.5, 0))
        elif i==9:
            color = ((0, 0, 0.5))
        elif i==10:
            color = ((0.5, 0.5, 0))
        elif i==11:
            color = ((0.5, 0, 0.5))
        elif i==12:
            color = ((0, 0.5, 0.5))
        elif i==13:
            color = ((0.5, 0.5, 0.5))

        p1=poin1s[i]
        p2=poin2s[i]
        p3=poin3s[i]
        p4=poin4s[i]
        plots[i].set_xdata(np.asarray((p2[0],p1[0])))
        plots[i].set_ydata(np.asarray((p2[1],p1[1])))
        plots[i].set_3d_properties(np.asarray((p2[2],p1[2])))
        plots[i].set_markersize(2)
        plots[i].set_color(color)
        plots[i+25].set_xdata(np.asarray((p1[0])))
        plots[i+25].set_ydata(np.asarray((p1[1])))
        plots[i+25].set_3d_properties(np.asarray((p1[2])))
    
        if p1[2]>1300 or p1[2]==0:
            if p4==1:
                plots[i+25].set_color((1,0,0))
            else:

                plots[i+25].set_color((0,0,0))
        elif p1[2]<=1300:
            if p4==1:
                plots[i+25].set_color((1,0,0))
            else:
                plots[i+25].set_color((0.1,0.9,0.1))
        #plots[i+15].set_color((0,0,0))
        plots[i+25].set_markersize(5)
        plots[i+40].set_xdata(np.asarray((p3[0],p1[0])))
        plots[i+40].set_ydata(np.asarray((p3[1],p1[1])))
        plots[i+40].set_3d_properties(np.asarray((p3[2],p1[2])))
        plots[i+40].set_markersize(2)
        if p1[2]>1300 or p1[2]==0:
            plots[i+40].set_color((0,0,0))
        elif p1[2]<=1300:# and p1[2]!=0:
            plots[i+40].set_color((0.1,0.9,0.1))
    fig.canvas.draw()
    plt.pause(0.001)
    #txt="\n\nFrame {}\n".format(frame) #default
    txt=''
    txt2=''
    if plot_data[0][-2]==1:
        txt2='default'
    elif plot_data[0][-2]==2:
        txt2='table'
    elif plot_data[0][-2]==3:
        txt2='presentations'
    elif plot_data[0][-2]==4:
        txt2='no activity'
    txt=txt+txt2         
    axes.title.set_text(txt)
    axes.title.set_fontsize(10)


frame=0
flag_enter=0
flag_exit=0
this_frame_exit=0



prev_frame_enter=1
prev_frame_exit=1

data_col=17
data_col_less=14

prev_frame_data=np.array([]).reshape(-1,data_col_less)
#prev_neck_data=np.array([]).reshape(-1,3)
all_data=np.array([]).reshape(-1,data_col)

flag2=0

smooth_window=0


#FOr Person ID

latest_person_id=0
person_id_list=np.array([]).reshape(-1,1)
far_threshold=6500
same_threshold=500

entering_frame=[]

room_length=11000






print("enter number")
person_present=int(input())
print("where to show? 1 for python and 0 for unity and 2 for none")
plot_flag=int(input())
send_to_unity_flag=not plot_flag

if  send_to_unity_flag:
    host, port = "127.0.0.1",65432
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    sock.connect((host, port))

T=time.time()

if plot_flag==1:
    fps=5
elif plot_flag and plot_flag!=1:
    fps=10


file_number=1
dtime=datetime.now()
dtime = dtime.strftime("%d_%m_%Y %H_%M_%S")
#dtime=dtime[:-10]
direc=os.getcwd()
direc=os.path.join(direc,'data collected')

path=os.path.join(direc,dtime)

frame_total=150*fps #default 300 seconds
remember_time=120 #How many previous seconds to remember for saving. Make it less than frame_total seconds
total_files_to_save=1000

close_to_door=[]
exit_event_frame=-remember_time*fps
enter_event_frame=-remember_time*fps
exit_frame_counter=0


os.mkdir(path)


gc.enable()

while True:

    print("frame ",frame," ,all data shape= ",all_data.shape)
    
    print("Person present ",person_present)
    #print("frame",frame)
    if file_number==total_files_to_save+1:
        break
    elap=time.time()-T  
    T=time.time()
    

    if frame==frame_total:# and person_present:
        if all_data.shape[0]:
            take_index_from=np.int32(np.max((all_data[0,0],frame-remember_time*fps)))
            print(" Take index FROM ",take_index_from)
            #take_index=np.min(np.where(all_data[:,0]==take_index_from)[0])
            take_index=np.where(all_data[:,0]==take_index_from)[0]
            
            if take_index.shape[0]:
                temporary_all=copy.deepcopy(all_data[take_index[0]:,:])
            else:                
                temporary_all=np.array([]).reshape(-1,data_col)
           
            all_data=copy.deepcopy(temporary_all)
            if np.mean(np.abs(all_data[:,1])):
            #if all_data.shape[0]:
                filename=path+'/'+f'{file_number:05d}'+'.npy'
                np.save(filename,all_data)
                print("     saving")
                file_number+=1
            else:
                print("    Not SAVING")
            all_data[:,0]-=remember_time*fps
            #print("HAHA ",all_data[0,0])
            entering_frame=[max((x-remember_time*fps),1) for x in entering_frame]#-10*fps
            print(entering_frame)
            prev_frame_enter=max(prev_frame_enter- remember_time*fps,1)
            prev_frame_exit=max(prev_frame_exit-remember_time*fps,1)
        frame-=remember_time*fps
        exit_event_frame=np.max((exit_event_frame-remember_time*fps,-remember_time*fps))
        gc.collect()

        
        

    
    if all_data.shape[0]>0 and person_present>0:
        recent_frame_data=np.where(all_data[:,0]==all_data[-1,0])[0]
        if recent_frame_data.shape[0]>0:
            plot_data=all_data[recent_frame_data,:]
            unity_data=convert_to_unity(plot_data)
            #print("unity_data= ",unity_data[:,1:10])
            if plot_flag==1:
                showing_plot(plot_data)
            if send_to_unity_flag:
                data_string=send_to_unity(unity_data)
                print("data_string= ",data_string[:20])
                T1=time.time()
                sock.sendall(data_string.encode("UTF-8"))
                receivedData = sock.recv(1024).decode("UTF-8")
                elap=1000*(time.time()-T1)
                print("Socekt comm takes miliseconds", elap)
                print(receivedData)
    if person_present==0 and plot_flag==1:
        plot_data=np.zeros((1,data_col))
        showing_plot(plot_data)

        
    frame+=1
    if frame==exit_event_frame+1 and flag_exit==1:
        close_to_door=[]
        exit_frame_counter=0

    if frame==1 and person_present:
        ######print("  frame: ",frame, "person_present: ",person_present)
        for i in range(person_present):
            person_id_list=np.vstack((person_id_list,i+1))
            entering_frame.append(frame)
        prev_frame_data=np.zeros((person_present,data_col_less))
        prev_frame_data[:,0]=frame
        prev_frame_data=np.hstack((prev_frame_data,person_id_list))
        all_data=np.zeros((person_present,data_col))
        all_data[:,0]=frame
        all_data[:,-3]=person_id_list.reshape(-1)
        latest_person_id=person_present
        activ=activity_detection(prev_frame_data)
        ######print("\n\n activ: ",activ,"\n\n")
        all_data[:,-2]=activ.reshape(-1)
        
        continue

    
    time_start = time.time()

    if on_off==2:
    #if 1==2:
        playback1.update()
        playback1.update()
        playback2.update()
        playback2.update()
        playback3.update()
        playback3.update()
        playback4.update()
        playback4.update()

    capture1 = playback1.update()
    bodyFrame1 = bodyTracker1.update(capture=capture1)

    
    capture2 = playback2.update()
    bodyFrame2 = bodyTracker2.update(capture=capture2)

   
    capture3 = playback3.update()
    bodyFrame3 = bodyTracker3.update(capture=capture3)

    
    capture4 = playback4.update()
    bodyFrame4 = bodyTracker4.update(capture=capture4)

    num_bodies1 = bodyFrame1.get_num_bodies()   
    num_bodies2 = bodyFrame2.get_num_bodies()    
    num_bodies3 = bodyFrame3.get_num_bodies()
    num_bodies4 = bodyFrame4.get_num_bodies()
    



    cam1s=[]
    cam2s=[]
    cam3s=[]
    cam4s=[]   


    if num_bodies1 > 0:
        far_flag=0
        cam1s=get_camera_data(num_bodies1,bodyFrame1,W4,b4)
        
    if num_bodies2 > 0:
        far_flag=0
        cam2s=get_camera_data(num_bodies2,bodyFrame2,W3,b3)
       
        
    if num_bodies3 > 0:
        far_flag=0
        cam3s=get_camera_data(num_bodies3,bodyFrame3,W2,b2) 
    
    
    if num_bodies4 > 0:
        far_flag=0
        cam4s=get_camera_data(num_bodies4,bodyFrame4,W1,b1)
        

        #Predicts Entry
        close_noses=np.array([]).reshape(-1,3)
        for noses in cam4s:
            nose=noses[1:4].reshape(1,3)[0]
            if nose[0]<900 and nose[0]>-100 and nose[1]>9000 and nose[1]<room_length:
                close_noses=np.concatenate((close_noses,nose.reshape(1,3)),axis=0)
        if close_noses.shape[0]>0: #Possible Entry Event
            print("****WE HAVE A POSSIBLE ENTRY EVENT")
            if person_present==0:
                person_present+=close_noses.shape[0]
                prev_frame_enter=frame
                
                flag_enter=1
                for nose in close_noses:
                    nose_enter=nose
                    print("Person entered")
                    print("Nose position: ",nose_enter)

                    latest_person_id+=1
                    person_id_list=np.vstack((person_id_list,latest_person_id))
                    #person_id_list.append(latest_person_id)
                    entering_frame.append(frame)

                    prev_frame_data=np.vstack((prev_frame_data,np.zeros(prev_frame_data.shape[1])))
                    prev_frame_data[-1,1:4]=nose_enter
                    prev_frame_data[-1,5:8]=[500,8500,1500]
                flag_enter=0

            else: #Previous person/ persons already present
                print("")
                for nose in close_noses:

                    indices=np.where(all_data[:,0]==all_data[-1,0])[0]

                    data_taken=all_data[indices,:]
                    #print("   Enter flag on and data taken shape=",data_taken.shape)
                    

                    dist_enter=np.zeros(data_taken.shape[0])
                    for i in range(data_taken.shape[0]):
                        #dist_exit[i]=np.linalg.norm(prev_frame_data[i,1:4]-nose_exit)
                        dist_enter[i]=np.linalg.norm(data_taken[i,1:4]-nose)
                        print("  Enter Distances: ",dist_enter, "for ID: ",data_taken[i,-3])

                    lowest_dist=np.min(dist_enter)
                    if lowest_dist>550:
                        print("  ### New person entered")
                        print("## Enter distance: ",lowest_dist)
                        print("## Entering Nose position: ",nose)
                        latest_person_id+=1
                        person_present+=1
                        person_id_list=np.vstack((person_id_list,latest_person_id))
                        #person_id_list.append(latest_person_id)
                        entering_frame.append(frame)
                        prev_frame_data=np.vstack((prev_frame_data,np.zeros(prev_frame_data.shape[1])))
                        prev_frame_data[-1,1:4]=nose
                        prev_frame_data[-1,5:8]=[500,8500,1500]

        
    
        for noses in cam4s: #Exit Prediction
            nose=noses[1:4].reshape(1,3)[0]
            p1=noses[5:8].reshape(1,3)[0]
            posvect=nose-p1
            posvect=posvect.reshape((1,3))

            posvect2=np.array([posvect[0,0],posvect[0,1]]).reshape(1,2)        


            #angle=np.arccos(np.dot(posvect,np.array([1,0,0]))/(np.linalg.norm(posvect)*np.linalg.norm(np.array([1,0,0]))))[0]
            angle=np.arccos(np.dot(posvect2,np.array([1,0]))/(np.linalg.norm(posvect2)*np.linalg.norm(np.array([1,0]))))[0]
            a=angle*180/np.pi


            #Exit  
            if 180/np.pi*angle>110 and nose[0]<1000 and nose[0]>-100 and nose[1]>9500 and nose[1]<room_length:
                #if frame-prev_frame_exit>fps and frame-prev_frame_enter>fps:
                if 1==1:   
                    nose_exit=nose
                    
                    flag_exit=1
                    exit_event_frame=frame
                    print("EXIT PREDICTED AT FRAME ",frame," WITH ANGLE ",a)

        
    
    frame_data=np.array([]).reshape(-1,data_col_less)
    temporary_frame_data=np.array([]).reshape(-1,data_col_less)
    
    
    if num_bodies1==0 and num_bodies2==0 and num_bodies3==0 and num_bodies4==0: #Either no person present or dropout by kinects
        ######print('no body')
        if person_id_list.shape[0]: #Means person present but dropped out
            
           
            frame_data=copy.deepcopy(prev_frame_data)
           
            frame_data[:,0]=frame
            prev_frame_data=copy.deepcopy(frame_data) #For next frame
    
            frame_data2=np.hstack((frame_data,np.zeros((frame_data.shape[0],2))))
            activ=activity_detection(frame_data)
            frame_data2[:,-2]=activ.reshape(-1)
            all_data=np.vstack((all_data,frame_data2))

            #To check if person is standing still
            if frame>2*fps:
                for m in range(person_id_list.shape[0]):
                    if frame-entering_frame[m]>2*fps:
                        considered_indices=np.where(all_data[:,0]==frame-2*fps)[0]
                        ######print("CONsidered_indices ",considered_indices)
                        for n in considered_indices:
                            if all_data[n,-3]==person_id_list[m]:
                                considered_indices2=n
                        
                        cons_data=copy.deepcopy(all_data[considered_indices2,1:4])
                        considered_positions=cons_data #np.mean(cons_data,axis=0)
                        current_indices=np.where(all_data[:,0]==frame)[0]
                        for n in current_indices:
                            if all_data[n,-3]==person_id_list[m]:
                                current_indices2=n
                        ######print("CURrent_indices2 ",current_indices2)
                        cur_dat=copy.deepcopy(all_data[current_indices2,1:4])
                        current_positions=cur_dat
                       
                        if np.linalg.norm(considered_positions-current_positions)<1000: #1 meter
                            frame_data2[m,-1]=1
                            all_data[current_indices2,-1]=1
                            
        


        if flag_exit==1 and frame>exit_event_frame+1:
            indices=np.where(all_data[:,0]==all_data[-1,0])[0]
            indices_prev=np.where(all_data[:,0]==all_data[-1,0]-1)[0]
            data_taken=all_data[indices,:]
            data_taken_prev=all_data[indices_prev,:]
            if data_taken.shape[0]>data_taken_prev.shape[0]:
                data_taken_prev=np.vstack((data_taken_prev,np.zeros((data_taken.shape[0]-data_taken_prev.shape[0],data_taken_prev.shape[1]))))
            #print("   Exit flag on and data taken shape=",data_taken.shape)
            

            dist_exit=np.zeros(data_taken.shape[0])
            data_exit=np.zeros((data_taken.shape[0],2))
            
            for i in range(data_taken.shape[0]):
                if data_taken[i,1]<1800 and data_taken[i,2]>8500:
                    dist_exit[i]=np.linalg.norm(data_taken[i,1:3]-data_taken_prev[i,1:3])+1
                    print("Temp data taken= ",data_taken[i,1:3],"")
                    print("Temp Exit distance= ",dist_exit[i],"  ID= ",data_taken[i,-3],"")
                    if dist_exit[i]==1:
                        close_to_door.append(data_taken[i,-3]) #Take the person ID
                        print(" AAdding to close to door distance= ",dist_exit[i], "  ID= ",data_taken[i,-3])
                    else:
                        print("  Not adding still")


                
                
                
            #print("         DISTANCE=,",dist_exit)
            exit_frame_counter+=1

            if exit_frame_counter==10*fps:
                print("*****Exit frame counter reached")
                print(" **Close to door list length= ",len(close_to_door))
                exit_frame_counter=0
                flag_exit=0
                unique_ids=np.unique(close_to_door)
                unique_ids.sort()
                unique_ids=unique_ids[::-1]
                for ind in range(len(unique_ids)):
                    print("****close to door count=",close_to_door.count(unique_ids[ind]),"  ID= ",unique_ids[ind])
                    if close_to_door.count(unique_ids[ind])>3*fps:
                        print("**Deleting person ID= ",unique_ids[ind])
                        del_idx=np.where(data_taken[:,-3]==unique_ids[ind])[0]
                        print("** index to delete= ",del_idx,"")
                        #del_idx=np.where(prev_frame_data[:,-3]==unique_ids[ind])[0]
                        prev_frame_data=np.delete(prev_frame_data,del_idx,0)
                        person_id_list=np.delete(person_id_list,del_idx,0)
                close_to_door=[]
                person_present=prev_frame_data.shape[0]
                print(" **Person present after deleting= ",person_present)
        continue
    else:
        if num_bodies1>0:
            temporary_frame_data=np.vstack((temporary_frame_data,cam1s))
            
        if num_bodies2>0:
            temporary_frame_data=np.vstack((temporary_frame_data,cam2s))
            
        if num_bodies3>0:
            temporary_frame_data=np.vstack((temporary_frame_data,cam3s))
            
        if num_bodies4>0:
            temporary_frame_data=np.vstack((temporary_frame_data,cam4s))
            
        
        #The following few lines are to remove the same person detected by different cameras
        allidx=np.array(list(range(temporary_frame_data.shape[0])))
        for k in range(temporary_frame_data.shape[0]):
            same=[]
            if k in allidx:
                for l in range(k+1,temporary_frame_data.shape[0]):                        
                    if np.abs(np.linalg.norm(temporary_frame_data[k,1:4]-temporary_frame_data[l,1:4]))<same_threshold:# or np.abs(np.linalg.norm(temporary_neck_data[k,:]-temporary_neck_data[l,:]))<600:
                        same.append(l)
                        same.append(k)
              
                same=np.unique(same).reshape(-1)
                if list(same)==[]:
                    frame_data=np.vstack((frame_data,temporary_frame_data[k,:]))
                    
                else:
                    confidences=temporary_frame_data[same,4]
                    max_confidence=np.argmax(confidences)
                    frame_data=np.vstack((frame_data,temporary_frame_data[same[max_confidence],:]))
                    allidx=[x for x in allidx if x not in same]
                   


    

    

    
    
    #if frame==exit_event_frame and flag_exit==1:
    #    close_to_door=[]
    #    exit_frame_counter=0

    if flag_exit==1 and frame>exit_event_frame+1 and person_present:
        indices=np.where(all_data[:,0]==all_data[-1,0])[0]
        indices_prev=np.where(all_data[:,0]==all_data[-1,0]-1)[0]
        data_taken=all_data[indices,:]
        data_taken_prev=all_data[indices_prev,:]
        if data_taken.shape[0]>data_taken_prev.shape[0]:
                data_taken_prev=np.vstack((data_taken_prev,np.zeros((data_taken.shape[0]-data_taken_prev.shape[0],data_taken_prev.shape[1]))))
        print("   Exit flag on and data taken shape=",data_taken.shape,"  prev frame data shape= ",data_taken_prev.shape)
        

        dist_exit=np.zeros(data_taken.shape[0])
        data_exit=np.zeros((data_taken.shape[0],2))
        
        for i in range(data_taken.shape[0]):
            if data_taken[i,1]<1800 and data_taken[i,2]>8500:
                dist_exit[i]=np.linalg.norm(data_taken[i,1:3]-data_taken_prev[i,1:3])+1
                print("Temp data taken= ",data_taken[i,1:3],"")
                print("Temp Exit distance= ",dist_exit[i],"  ID= ",data_taken[i,-3],"")
                if dist_exit[i]==1:
                    close_to_door.append(data_taken[i,-3]) #Take the person ID
                    print(" AAdding to close to door distance= ",dist_exit[i], "  ID= ",data_taken[i,-3])
                else:
                    print("  Not adding still")
        exit_frame_counter+=1

        if exit_frame_counter==10*fps:
            print("*****Exit frame counter reached")
            exit_frame_counter=0
            flag_exit=0
            unique_ids=np.unique(close_to_door)
            unique_ids.sort()
            unique_ids=unique_ids[::-1]
            for ind in range(len(unique_ids)):
                print("****close to door count=",close_to_door.count(unique_ids[ind]),"  ID= ",unique_ids[ind])
                if close_to_door.count(unique_ids[ind])>3*fps:
                    print("**Deleting person ID= ",unique_ids[ind])
                    del_idx=np.where(data_taken[:,-3]==unique_ids[ind])[0]
                    print("** index to delete= ",del_idx,"")
                    prev_frame_data=np.delete(prev_frame_data,del_idx,0)
                    person_id_list=np.delete(person_id_list,del_idx,0)
            close_to_door=[]
            person_present=prev_frame_data.shape[0]

     
       
        
    
    #Give Person ID
    #ID Assignment Hungarian Algorithm
    distances=np.zeros((frame_data.shape[0],prev_frame_data.shape[0]))
    ######print("distances shape: ",distances.shape)
    for i in range(frame_data.shape[0]):
        for j in range(prev_frame_data.shape[0]):
            distances[i,j]=np.linalg.norm(frame_data[i,1:4]-prev_frame_data[j,1:4])
           
    row,col=linear_sum_assignment(distances)

    temp=copy.deepcopy(frame_data)


    if frame_data.shape[0]==prev_frame_data.shape[0]:
        frame_data[col,:]=temp[:,:]
        frame_data=np.hstack((frame_data,person_id_list))
      
        prev_frame_data=copy.deepcopy(frame_data)

        ######print("  changed_data added to all",frame_data[:,1:4])
        
    
    elif frame_data.shape[0]<prev_frame_data.shape[0]: #Sudden Disappearance      

        frame_data=copy.deepcopy(prev_frame_data[:,0:-1])
        frame_data[:,0]=frame
        frame_data[col[0:frame_data.shape[0]],:]=temp[:,:]
        frame_data=np.hstack((frame_data,person_id_list))
        prev_frame_data=copy.deepcopy(frame_data)


        
    
    
    elif frame_data.shape[0]>prev_frame_data.shape[0]: #Sudden Apperearance
        ######print("SUDDENNNNNN Apperearance")
        temp=copy.deepcopy(frame_data)
        frame_data=temp[row,:]
        temp=copy.deepcopy(frame_data)
        frame_data[col,:]=temp[:,:]
        now_idx=list(range(frame_data.shape[0]))
        del_idx=[x for x in now_idx if x not in col]
        frame_data=np.delete(frame_data,del_idx,0)
        frame_data=np.hstack((frame_data,person_id_list))

    
    frame_data2=np.hstack((frame_data,np.zeros((frame_data.shape[0],2))))
    activ=activity_detection(frame_data)
    ######print("\n\n activ: ",activ,"\n\n")
    frame_data2[:,-2]=activ.reshape(-1)

    
    all_data=np.vstack((all_data,frame_data2))

    ### TRY adding stationary flag for a person who is not moving for 2*fps frames
    
    if frame>2*fps:
        #print("Hello")
        for m in range(person_id_list.shape[0]):
            if frame-entering_frame[m]>2*fps:
                considered_indices=np.where(all_data[:,0]==frame-2*fps)[0]
                #print("CONsidered_indices ",considered_indices)
                considered_indices2=m
                for n in considered_indices:
                    if all_data[n,-3]==person_id_list[m]:
                        considered_indices2=n
                
                ######print("CONsidered_indices2 ",considered_indices2)
                cons_data=copy.deepcopy(all_data[considered_indices2,1:4])
                ######print("cons_data ",cons_data[1:4])
                considered_positions=cons_data
                current_indices=np.where(all_data[:,0]==frame)[0]
                for n in current_indices:
                    if all_data[n,-3]==person_id_list[m]:
                        current_indices2=n
                
                ######print("CURrent_indices2 ",current_indices2)
                cur_dat=copy.deepcopy(all_data[current_indices2,1:4])
                current_positions=cur_dat
                ######print("for id=",m+1, "dist=", np.linalg.norm(considered_positions-current_positions))
                if np.linalg.norm(considered_positions-current_positions)<1000: #2 meter
                    frame_data2[m,-1]=1
                    
                    all_data[current_indices2,-1]=1
                    
    
    prev_frame_data=copy.deepcopy(frame_data) #For next frame. Now prev_frame_data.shape[1]=data_col_less+1   
    
    #smoothing
    
    if frame>smooth_window and smooth_window!=0:

        b=[]
        for i in range(frame-smooth_window,frame):
            a=np.where(all_data[:,0]==i)
            
            if a[0].size>0:

                get=np.array(a[0]).reshape(-1)
                
                for j in get:
                    b.append(j)

               
        b=np.array(b).reshape(-1)
        
        if b.size>0:
            considered_data=all_data[b,:].reshape(-1,all_data.shape[1])
            ######print("considered_data ",considered_data.shape)
            
            for i in range(int(np.max(person_id_list)+1)):
                c=[]
                c=np.where(considered_data[:,-1]==i)[0]
                
                if c!=[]:
                    d1=np.mean(considered_data[c,1:4],axis=0)
                    d2=np.mean(considered_data[c,11:data_col_less],axis=0)


                    e=b[c]
                    all_data[e,1:4]=d1
                    all_data[e,11:14]=d2
    
    
######print("FINISHED")
playback1.close()
playback2.close()
playback3.close()
playback4.close()
# Out:
# enter 1 for online and 2 for offline
# enter number
# where to show? 1 for python and 0 for unity and 2 for none
# frame  0  ,all data shape=  (0, 17)
# Person present  0
# frame  1  ,all data shape=  (0, 17)
# Person present  0
# frame  2  ,all data shape=  (0, 17)
# Person present  0
# frame  3  ,all data shape=  (0, 17)
# Person present  0
# frame  4  ,all data shape=  (0, 17)
# Person present  0
# frame  5  ,all data shape=  (0, 17)
# Person present  0
# frame  6  ,all data shape=  (0, 17)
# Person present  0
# frame  7  ,all data shape=  (0, 17)
# Person present  0
# frame  8  ,all data shape=  (0, 17)
# Person present  0
# frame  9  ,all data shape=  (0, 17)
# Person present  0
# frame  10  ,all data shape=  (0, 17)
# Person present  0
# frame  11  ,all data shape=  (0, 17)
# Person present  0
# frame  12  ,all data shape=  (0, 17)
# Person present  0
# frame  13  ,all data shape=  (0, 17)
# Person present  0
# frame  14  ,all data shape=  (0, 17)
# Person present  0
# frame  15  ,all data shape=  (0, 17)
# Person present  0
# frame  16  ,all data shape=  (0, 17)
# Person present  0
# frame  17  ,all data shape=  (0, 17)
# Person present  0
# frame  18  ,all data shape=  (0, 17)
# Person present  0
# frame  19  ,all data shape=  (0, 17)
# Person present  0
# frame  20  ,all data shape=  (0, 17)
# Person present  0
# frame  21  ,all data shape=  (0, 17)
# Person present  0
# frame  22  ,all data shape=  (0, 17)
# Person present  0
# frame  23  ,all data shape=  (0, 17)
# Person present  0
# frame  24  ,all data shape=  (0, 17)
# Person present  0
# frame  25  ,all data shape=  (0, 17)
# Person present  0
# frame  26  ,all data shape=  (0, 17)
# Person present  0
# frame  27  ,all data shape=  (0, 17)
# Person present  0
# frame  28  ,all data shape=  (0, 17)
# Person present  0
# frame  29  ,all data shape=  (0, 17)
# Person present  0
# frame  30  ,all data shape=  (0, 17)
# Person present  0
# frame  31  ,all data shape=  (0, 17)
# Person present  0
# frame  32  ,all data shape=  (0, 17)
# Person present  0
# frame  33  ,all data shape=  (0, 17)
# Person present  0
# frame  34  ,all data shape=  (0, 17)
# Person present  0
# frame  35  ,all data shape=  (0, 17)
# Person present  0
# frame  36  ,all data shape=  (0, 17)
# Person present  0
# frame  37  ,all data shape=  (0, 17)
# Person present  0
# frame  38  ,all data shape=  (0, 17)
# Person present  0
# frame  39  ,all data shape=  (0, 17)
# Person present  0
# frame  40  ,all data shape=  (0, 17)
# Person present  0
# frame  41  ,all data shape=  (0, 17)
# Person present  0
# frame  42  ,all data shape=  (0, 17)
# Person present  0
# frame  43  ,all data shape=  (0, 17)
# Person present  0
# frame  44  ,all data shape=  (0, 17)
# Person present  0
# frame  45  ,all data shape=  (0, 17)
# Person present  0
# frame  46  ,all data shape=  (0, 17)
# Person present  0
# frame  47  ,all data shape=  (0, 17)
# Person present  0
# frame  48  ,all data shape=  (0, 17)
# Person present  0
# frame  49  ,all data shape=  (0, 17)
# Person present  0
# frame  50  ,all data shape=  (0, 17)
# Person present  0
# frame  51  ,all data shape=  (0, 17)
# Person present  0
# frame  52  ,all data shape=  (0, 17)
# Person present  0
# frame  53  ,all data shape=  (0, 17)
# Person present  0
# frame  54  ,all data shape=  (0, 17)
# Person present  0
# frame  55  ,all data shape=  (0, 17)
# Person present  0
# frame  56  ,all data shape=  (0, 17)
# Person present  0
# frame  57  ,all data shape=  (0, 17)
# Person present  0
# frame  58  ,all data shape=  (0, 17)
# Person present  0
# frame  59  ,all data shape=  (0, 17)
# Person present  0
# frame  60  ,all data shape=  (0, 17)
# Person present  0
# frame  61  ,all data shape=  (0, 17)
# Person present  0
# frame  62  ,all data shape=  (0, 17)
# Person present  0
# frame  63  ,all data shape=  (0, 17)
# Person present  0
# frame  64  ,all data shape=  (0, 17)
# Person present  0
# frame  65  ,all data shape=  (0, 17)
# Person present  0
# frame  66  ,all data shape=  (0, 17)
# Person present  0
# frame  67  ,all data shape=  (0, 17)
# Person present  0
# frame  68  ,all data shape=  (0, 17)
# Person present  0
# frame  69  ,all data shape=  (0, 17)
# Person present  0
# frame  70  ,all data shape=  (0, 17)
# Person present  0
# frame  71  ,all data shape=  (0, 17)
# Person present  0
# frame  72  ,all data shape=  (0, 17)
# Person present  0
# frame  73  ,all data shape=  (0, 17)
# Person present  0
# frame  74  ,all data shape=  (0, 17)
# Person present  0
# frame  75  ,all data shape=  (0, 17)
# Person present  0
# frame  76  ,all data shape=  (0, 17)
# Person present  0
# frame  77  ,all data shape=  (0, 17)
# Person present  0
# frame  78  ,all data shape=  (0, 17)
# Person present  0
# frame  79  ,all data shape=  (0, 17)
# Person present  0
# frame  80  ,all data shape=  (0, 17)
# Person present  0
# frame  81  ,all data shape=  (0, 17)
# Person present  0
# frame  82  ,all data shape=  (0, 17)
# Person present  0
# frame  83  ,all data shape=  (0, 17)
# Person present  0
# frame  84  ,all data shape=  (0, 17)
# Person present  0
# frame  85  ,all data shape=  (0, 17)
# Person present  0
# frame  86  ,all data shape=  (0, 17)
# Person present  0
# frame  87  ,all data shape=  (0, 17)
# Person present  0
# frame  88  ,all data shape=  (0, 17)
# Person present  0
# frame  89  ,all data shape=  (0, 17)
# Person present  0
# frame  90  ,all data shape=  (0, 17)
# Person present  0
# frame  91  ,all data shape=  (0, 17)
# Person present  0
# frame  92  ,all data shape=  (0, 17)
# Person present  0
# frame  93  ,all data shape=  (0, 17)
# Person present  0
# frame  94  ,all data shape=  (0, 17)
# Person present  0
# frame  95  ,all data shape=  (0, 17)
# Person present  0
# frame  96  ,all data shape=  (0, 17)
# Person present  0
# frame  97  ,all data shape=  (0, 17)
# Person present  0
# frame  98  ,all data shape=  (0, 17)
# Person present  0
# frame  99  ,all data shape=  (0, 17)
# Person present  0
# frame  100  ,all data shape=  (0, 17)
# Person present  0
# frame  101  ,all data shape=  (0, 17)
# Person present  0
# frame  102  ,all data shape=  (0, 17)
# Person present  0
# frame  103  ,all data shape=  (0, 17)
# Person present  0
# frame  104  ,all data shape=  (0, 17)
# Person present  0
# frame  105  ,all data shape=  (0, 17)
# Person present  0
# frame  106  ,all data shape=  (0, 17)
# Person present  0
# frame  107  ,all data shape=  (0, 17)
# Person present  0
# frame  108  ,all data shape=  (0, 17)
# Person present  0
# frame  109  ,all data shape=  (0, 17)
# Person present  0
# frame  110  ,all data shape=  (0, 17)
# Person present  0
# frame  111  ,all data shape=  (0, 17)
# Person present  0
# frame  112  ,all data shape=  (0, 17)
# Person present  0
# frame  113  ,all data shape=  (0, 17)
# Person present  0
# frame  114  ,all data shape=  (0, 17)
# Person present  0
# frame  115  ,all data shape=  (0, 17)
# Person present  0
# frame  116  ,all data shape=  (0, 17)
# Person present  0
# frame  117  ,all data shape=  (0, 17)
# Person present  0
# frame  118  ,all data shape=  (0, 17)
# Person present  0
# frame  119  ,all data shape=  (0, 17)
# Person present  0
# frame  120  ,all data shape=  (0, 17)
# Person present  0
# frame  121  ,all data shape=  (0, 17)
# Person present  0
# frame  122  ,all data shape=  (0, 17)
# Person present  0
# frame  123  ,all data shape=  (0, 17)
# Person present  0
# frame  124  ,all data shape=  (0, 17)
# Person present  0
# frame  125  ,all data shape=  (0, 17)
# Person present  0
# frame  126  ,all data shape=  (0, 17)
# Person present  0
# frame  127  ,all data shape=  (0, 17)
# Person present  0
# frame  128  ,all data shape=  (0, 17)
# Person present  0
# frame  129  ,all data shape=  (0, 17)
# Person present  0
# frame  130  ,all data shape=  (0, 17)
# Person present  0
# frame  131  ,all data shape=  (0, 17)
# Person present  0
# frame  132  ,all data shape=  (0, 17)
# Person present  0
# frame  133  ,all data shape=  (0, 17)
# Person present  0
# frame  134  ,all data shape=  (0, 17)
# Person present  0
# frame  135  ,all data shape=  (0, 17)
# Person present  0
# frame  136  ,all data shape=  (0, 17)
# Person present  0
# frame  137  ,all data shape=  (0, 17)
# Person present  0
# frame  138  ,all data shape=  (0, 17)
# Person present  0
# frame  139  ,all data shape=  (0, 17)
# Person present  0
# frame  140  ,all data shape=  (0, 17)
# Person present  0
# frame  141  ,all data shape=  (0, 17)
# Person present  0
# frame  142  ,all data shape=  (0, 17)
# Person present  0
# frame  143  ,all data shape=  (0, 17)
# Person present  0
# frame  144  ,all data shape=  (0, 17)
# Person present  0
# frame  145  ,all data shape=  (0, 17)
# Person present  0
# frame  146  ,all data shape=  (0, 17)
# Person present  0
# frame  147  ,all data shape=  (0, 17)
# Person present  0
# frame  148  ,all data shape=  (0, 17)
# Person present  0
# frame  149  ,all data shape=  (0, 17)
# Person present  0
# ** index to delete=  [0]
# frame  150  ,all data shape=  (0, 17)
# Person present  0
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
# Person entered
# Nose position:  [   73.02943221 10073.36276559  1485.01607161]
# frame  151  ,all data shape=  (1, 17)
# Person present  1
# ** index to delete=  [0]
# frame  152  ,all data shape=  (2, 17)
# Person present  1
# ** index to delete=  [0]
# frame  153  ,all data shape=  (3, 17)
# Person present  1
# ** index to delete=  [0]
# frame  154  ,all data shape=  (4, 17)
# Person present  1
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [420.42359591] for ID:  1.0
# frame  155  ,all data shape=  (5, 17)
# Person present  1
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [134.01865542] for ID:  1.0
# frame  156  ,all data shape=  (6, 17)
# Person present  1
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [197.13447187] for ID:  1.0
# frame  157  ,all data shape=  (7, 17)
# Person present  1
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [177.90165823] for ID:  1.0
# frame  158  ,all data shape=  (8, 17)
# Person present  1
# ** index to delete=  []
# frame  159  ,all data shape=  (9, 17)
# Person present  1
# ** index to delete=  []
# frame  160  ,all data shape=  (10, 17)
# Person present  1
# ** index to delete=  []
# frame  161  ,all data shape=  (11, 17)
# Person present  1
# ** index to delete=  []
# frame  162  ,all data shape=  (12, 17)
# Person present  1
# ** index to delete=  []
# frame  163  ,all data shape=  (13, 17)
# Person present  1
# ** index to delete=  []
# frame  164  ,all data shape=  (14, 17)
# Person present  1
# ** index to delete=  []
# frame  165  ,all data shape=  (15, 17)
# Person present  1
# ** index to delete=  []
# frame  166  ,all data shape=  (16, 17)
# Person present  1
# ** index to delete=  []
# frame  167  ,all data shape=  (17, 17)
# Person present  1
# ** index to delete=  []
# frame  168  ,all data shape=  (18, 17)
# Person present  1
# ** index to delete=  []
# frame  169  ,all data shape=  (19, 17)
# Person present  1
# ** index to delete=  []
# frame  170  ,all data shape=  (20, 17)
# Person present  1
# ** index to delete=  []
# frame  171  ,all data shape=  (21, 17)
# Person present  1
# ** index to delete=  []
# frame  172  ,all data shape=  (22, 17)
# Person present  1
# ** index to delete=  []
# frame  173  ,all data shape=  (23, 17)
# Person present  1
# ** index to delete=  []
# frame  174  ,all data shape=  (24, 17)
# Person present  1
# ** index to delete=  []
# ** index to delete=  []
# frame  175  ,all data shape=  (25, 17)
# Person present  1
# ** index to delete=  []
# ** index to delete=  []
# frame  176  ,all data shape=  (26, 17)
# Person present  1
# ** index to delete=  []
# ** index to delete=  []
# frame  177  ,all data shape=  (27, 17)
# Person present  1
# ** index to delete=  []
# ** index to delete=  []
# frame  178  ,all data shape=  (28, 17)
# Person present  1
# ** index to delete=  []
# frame  179  ,all data shape=  (29, 17)
# Person present  1
# ** index to delete=  []
# ** index to delete=  []
# frame  180  ,all data shape=  (30, 17)
# Person present  1
# ** index to delete=  []
# ** index to delete=  []
# frame  181  ,all data shape=  (31, 17)
# Person present  1
# ** index to delete=  []
# ** index to delete=  []
# frame  182  ,all data shape=  (32, 17)
# Person present  1
# ** index to delete=  []
# frame  183  ,all data shape=  (33, 17)
# Person present  1
# ** index to delete=  []
# ** index to delete=  [1]
# frame  184  ,all data shape=  (34, 17)
# Person present  1
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3628.07510948] for ID:  1.0
#   ### New person entered
# ## Enter distance:  3628.0751094760976
# ## Entering Nose position:  [  319.74638024 10121.17535388  1381.87197844]
# frame  185  ,all data shape=  (36, 17)
# Person present  2
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3532.84962297    0.        ] for ID:  1.0
#   Enter Distances:  [3532.84962297   68.43244844] for ID:  2.0
# frame  186  ,all data shape=  (38, 17)
# Person present  2
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3378.40938905    0.        ] for ID:  1.0
#   Enter Distances:  [3378.40938905  400.18120895] for ID:  2.0
# frame  187  ,all data shape=  (40, 17)
# Person present  2
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3307.2378203    0.       ] for ID:  1.0
#   Enter Distances:  [3307.2378203    80.94442538] for ID:  2.0
# frame  188  ,all data shape=  (42, 17)
# Person present  2
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3201.98282319    0.        ] for ID:  1.0
#   Enter Distances:  [3201.98282319  135.2479205 ] for ID:  2.0
# frame  189  ,all data shape=  (44, 17)
# Person present  2
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3136.96079032    0.        ] for ID:  1.0
#   Enter Distances:  [3136.96079032  118.71394189] for ID:  2.0
# frame  190  ,all data shape=  (46, 17)
# Person present  2
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3162.07305418    0.        ] for ID:  1.0
#   Enter Distances:  [3162.07305418  103.85085459] for ID:  2.0
# frame  191  ,all data shape=  (48, 17)
# Person present  2
# ** index to delete=  []
# frame  192  ,all data shape=  (50, 17)
# Person present  2
# ** index to delete=  []
# frame  193  ,all data shape=  (52, 17)
# Person present  2
# ** index to delete=  []
# ** index to delete=  []
# frame  194  ,all data shape=  (54, 17)
# Person present  2
# ** index to delete=  []
# ** index to delete=  []
# frame  195  ,all data shape=  (56, 17)
# Person present  2
# ** index to delete=  []
# ** index to delete=  []
# frame  196  ,all data shape=  (58, 17)
# Person present  2
# ** index to delete=  []
# ** index to delete=  []
# frame  197  ,all data shape=  (60, 17)
# Person present  2
# ** index to delete=  []
# ** index to delete=  []
# frame  198  ,all data shape=  (62, 17)
# Person present  2
# ** index to delete=  []
# ** index to delete=  []
# frame  199  ,all data shape=  (64, 17)
# Person present  2
# ** index to delete=  []
# ** index to delete=  []
# frame  200  ,all data shape=  (66, 17)
# Person present  2
# ** index to delete=  []
# ** index to delete=  []
# frame  201  ,all data shape=  (68, 17)
# Person present  2
# ** index to delete=  []
# ** index to delete=  []
# frame  202  ,all data shape=  (70, 17)
# Person present  2
# ** index to delete=  []
# ** index to delete=  []
# frame  203  ,all data shape=  (72, 17)
# Person present  2
# ** index to delete=  []
# ** index to delete=  []
# frame  204  ,all data shape=  (74, 17)
# Person present  2
# ** index to delete=  []
# ** index to delete=  []
# frame  205  ,all data shape=  (76, 17)
# Person present  2
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [4543.3676529    0.       ] for ID:  1.0
#   Enter Distances:  [4543.3676529  2105.53888589] for ID:  2.0
#   ### New person entered
# ## Enter distance:  2105.5388858912106
# ## Entering Nose position:  [  226.64361605 10139.06459647  1460.52215517]
# frame  206  ,all data shape=  (79, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [4508.74491697    0.            0.        ] for ID:  1.0
#   Enter Distances:  [4508.74491697 2203.56370455    0.        ] for ID:  2.0
#   Enter Distances:  [4508.74491697 2203.56370455   70.09279564] for ID:  3.0
# frame  207  ,all data shape=  (82, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
# frame  208  ,all data shape=  (85, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [4489.70945627    0.            0.        ] for ID:  1.0
#   Enter Distances:  [4489.70945627 2310.58477447    0.        ] for ID:  2.0
#   Enter Distances:  [4489.70945627 2310.58477447   91.93475948] for ID:  3.0
# frame  209  ,all data shape=  (88, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [4434.20051765    0.            0.        ] for ID:  1.0
#   Enter Distances:  [4434.20051765 2311.35804236    0.        ] for ID:  2.0
#   Enter Distances:  [4434.20051765 2311.35804236  114.20157617] for ID:  3.0
# EXIT PREDICTED AT FRAME  210  WITH ANGLE  141.1609043249895
# frame  210  ,all data shape=  (91, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [4332.18726126    0.            0.        ] for ID:  1.0
#   Enter Distances:  [4332.18726126 2216.13289313    0.        ] for ID:  2.0
#   Enter Distances:  [4332.18726126 2216.13289313  107.88883167] for ID:  3.0
# EXIT PREDICTED AT FRAME  211  WITH ANGLE  148.29360203073392
# frame  211  ,all data shape=  (94, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [4128.24669322    0.            0.        ] for ID:  1.0
#   Enter Distances:  [4128.24669322 2005.61173344    0.        ] for ID:  2.0
#   Enter Distances:  [4128.24669322 2005.61173344  230.46474785] for ID:  3.0
# frame  212  ,all data shape=  (97, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [4093.7322898    0.           0.       ] for ID:  1.0
#   Enter Distances:  [4093.7322898  2028.70155963    0.        ] for ID:  2.0
#   Enter Distances:  [4093.7322898  2028.70155963   47.33920151] for ID:  3.0
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [ 530.5509977  9904.04216831]
# Temp Exit distance=  229.13607034809613   ID=  3.0
#   Not adding still
# frame  213  ,all data shape=  (100, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3839.74732134    0.            0.        ] for ID:  1.0
#   Enter Distances:  [3839.74732134 1830.12312252    0.        ] for ID:  2.0
#   Enter Distances:  [3839.74732134 1830.12312252  219.02054698] for ID:  3.0
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [ 553.84717704 9862.85842273]
# Temp Exit distance=  48.31609527249363   ID=  3.0
#   Not adding still
# frame  214  ,all data shape=  (103, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3731.18978512    0.            0.        ] for ID:  1.0
#   Enter Distances:  [3731.18978512 1747.29718764    0.        ] for ID:  2.0
#   Enter Distances:  [3731.18978512 1747.29718764  114.28473214] for ID:  3.0
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [ 742.32883932 9776.31972031]
# Temp Exit distance=  208.3988525404306   ID=  3.0
#   Not adding still
# frame  215  ,all data shape=  (106, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3711.32173916    0.            0.        ] for ID:  1.0
#   Enter Distances:  [3711.32173916 1717.63285965    0.        ] for ID:  2.0
#   Enter Distances:  [3711.32173916 1717.63285965   91.61331781] for ID:  3.0
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [ 834.63184894 9712.99883507]
# Temp Exit distance=  112.93471352454023   ID=  3.0
#   Not adding still
# frame  216  ,all data shape=  (109, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [ 809.16512182 9634.01406969]
# Temp Exit distance=  83.98883871713242   ID=  3.0
#   Not adding still
# frame  217  ,all data shape=  (112, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [ 910.9108865  9555.14808223]
# Temp Exit distance=  129.73245360076655   ID=  3.0
#   Not adding still
# frame  218  ,all data shape=  (115, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [ 952.48739022 9485.4688309 ]
# Temp Exit distance=  82.14064165276531   ID=  3.0
#   Not adding still
# frame  219  ,all data shape=  (118, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [ 975.86606725 9385.17417329]
# Temp Exit distance=  103.9834010113014   ID=  3.0
#   Not adding still
# frame  220  ,all data shape=  (121, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [ 999.60848833 9277.19268429]
# Temp Exit distance=  111.56086344079519   ID=  3.0
#   Not adding still
# frame  221  ,all data shape=  (124, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1004.60207878 9166.21673099]
# Temp Exit distance=  112.08824491271587   ID=  3.0
#   Not adding still
# frame  222  ,all data shape=  (127, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1088.92552613 9110.71886365]
# Temp Exit distance=  101.94779369608263   ID=  3.0
#   Not adding still
# frame  223  ,all data shape=  (130, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1156.91934053 9098.32823932]
# Temp Exit distance=  70.11357586387274   ID=  3.0
#   Not adding still
# frame  224  ,all data shape=  (133, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1054.0680097  8921.00812598]
# Temp Exit distance=  205.98980181252622   ID=  3.0
#   Not adding still
# frame  225  ,all data shape=  (136, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1091.65329854 8840.33225637]
# Temp Exit distance=  90.0014037766282   ID=  3.0
#   Not adding still
# frame  226  ,all data shape=  (139, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1129.70012694 8772.10692888]
# Temp Exit distance=  79.11694094839173   ID=  3.0
#   Not adding still
# frame  227  ,all data shape=  (142, 17)
# Person present  3
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1144.16612208 8730.60485036]
# Temp Exit distance=  44.95096740931728   ID=  3.0
#   Not adding still
# frame  228  ,all data shape=  (145, 17)
# Person present  3
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1129.46823644 8703.77119699]
# Temp Exit distance=  31.595306757330608   ID=  3.0
#   Not adding still
# frame  229  ,all data shape=  (148, 17)
# Person present  3
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  230  ,all data shape=  (151, 17)
# Person present  3
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  231  ,all data shape=  (154, 17)
# Person present  3
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  232  ,all data shape=  (157, 17)
# Person present  3
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  233  ,all data shape=  (160, 17)
# Person present  3
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  234  ,all data shape=  (163, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  235  ,all data shape=  (166, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  236  ,all data shape=  (169, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  237  ,all data shape=  (172, 17)
# Person present  3
# ** index to delete=  []
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  238  ,all data shape=  (175, 17)
# Person present  3
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3741.74729605    0.            0.        ] for ID:  1.0
#   Enter Distances:  [3741.74729605 2392.80344159    0.        ] for ID:  2.0
#   Enter Distances:  [3741.74729605 2392.80344159 1889.5115771 ] for ID:  3.0
#   ### New person entered
# ## Enter distance:  1889.5115771013413
# ## Entering Nose position:  [  518.03092643 10110.46480467  1603.91144087]
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  239  ,all data shape=  (179, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3620.37613691    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [3620.37613691 2339.78740582    0.            0.        ] for ID:  2.0
#   Enter Distances:  [3620.37613691 2339.78740582 1785.569657      0.        ] for ID:  3.0
#   Enter Distances:  [3620.37613691 2339.78740582 1785.569657    106.32497355] for ID:  4.0
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [  518.03092643 10110.46480467]
# Temp Exit distance=  10124.727308026539   ID=  4.0
#   Not adding still
# frame  240  ,all data shape=  (183, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3479.72954176    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [3479.72954176 2304.94615935    0.            0.        ] for ID:  2.0
#   Enter Distances:  [3479.72954176 2304.94615935 1718.91390128    0.        ] for ID:  3.0
#   Enter Distances:  [3479.72954176 2304.94615935 1718.91390128  127.11412195] for ID:  4.0
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [  565.43532695 10020.96892586]
# Temp Exit distance=  102.27531542016354   ID=  4.0
#   Not adding still
# frame  241  ,all data shape=  (187, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3400.17613309    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [3400.17613309 2300.60536466    0.            0.        ] for ID:  2.0
#   Enter Distances:  [3400.17613309 2300.60536466 1654.35969487    0.        ] for ID:  3.0
#   Enter Distances:  [3400.17613309 2300.60536466 1654.35969487   71.28113355] for ID:  4.0
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [ 682.71210142 9983.90638129]
# Temp Exit distance=  123.99379675310404   ID=  4.0
#   Not adding still
# frame  242  ,all data shape=  (191, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3363.02536738    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [3363.02536738 2358.68535818    0.            0.        ] for ID:  2.0
#   Enter Distances:  [3363.02536738 2358.68535818 2963.18092094    0.        ] for ID:  3.0
#   Enter Distances:  [3363.02536738 2358.68535818 2963.18092094   47.54997371] for ID:  4.0
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [ 728.01499845 9928.87561549]
# Temp Exit distance=  72.279293372547   ID=  4.0
#   Not adding still
# frame  243  ,all data shape=  (195, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3248.05468634    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [3248.05468634 2243.73303112    0.            0.        ] for ID:  2.0
#   Enter Distances:  [3248.05468634 2243.73303112 2875.3758886     0.        ] for ID:  3.0
#   Enter Distances:  [3248.05468634 2243.73303112 2875.3758886   124.39453364] for ID:  4.0
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [ 764.75211442 9902.18281391]
# Temp Exit distance=  46.41058628066159   ID=  4.0
#   Not adding still
# frame  244  ,all data shape=  (199, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [ 867.83601661 9835.74106811]
# Temp Exit distance=  123.64092495959962   ID=  4.0
#   Not adding still
# frame  245  ,all data shape=  (203, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [ 957.58436509 9800.4908191 ]
# Temp Exit distance=  97.42274685449328   ID=  4.0
#   Not adding still
# frame  246  ,all data shape=  (207, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1024.87033838 9764.72148691]
# Temp Exit distance=  77.20267269894451   ID=  4.0
#   Not adding still
# frame  247  ,all data shape=  (211, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1090.50504437 9702.26344113]
# Temp Exit distance=  91.60310211528999   ID=  4.0
#   Not adding still
# frame  248  ,all data shape=  (215, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1153.94358042 9659.58493545]
# Temp Exit distance=  77.45850315011366   ID=  4.0
#   Not adding still
# frame  249  ,all data shape=  (219, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1208.99623562 9611.50262376]
# Temp Exit distance=  74.09379960937076   ID=  4.0
#   Not adding still
# frame  250  ,all data shape=  (223, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1241.86631818 9562.50022708]
# Temp Exit distance=  60.0057387684348   ID=  4.0
#   Not adding still
# frame  251  ,all data shape=  (227, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1308.2035955  9540.86755517]
# Temp Exit distance=  70.77540294968186   ID=  4.0
#   Not adding still
# frame  252  ,all data shape=  (231, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1307.40297554 9495.24379629]
# Temp Exit distance=  46.63078310034115   ID=  4.0
#   Not adding still
# frame  253  ,all data shape=  (235, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1349.57724606 9472.34044424]
# Temp Exit distance=  48.99200588475975   ID=  4.0
#   Not adding still
# frame  254  ,all data shape=  (239, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1385.60100648 9446.02912392]
# Temp Exit distance=  45.60938121191708   ID=  4.0
#   Not adding still
# frame  255  ,all data shape=  (243, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1442.11280077 9447.75906873]
# Temp Exit distance=  57.53826671429419   ID=  4.0
#   Not adding still
# frame  256  ,all data shape=  (247, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1498.8341872  9455.63889344]
# Temp Exit distance=  58.266109659600666   ID=  4.0
#   Not adding still
# frame  257  ,all data shape=  (251, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1604.0378206  9492.50315817]
# Temp Exit distance=  112.47546140329592   ID=  4.0
#   Not adding still
# frame  258  ,all data shape=  (255, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1739.25404372 9557.47622281]
# Temp Exit distance=  151.0164195081046   ID=  4.0
#   Not adding still
# frame  259  ,all data shape=  (259, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  260  ,all data shape=  (263, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  261  ,all data shape=  (267, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  262  ,all data shape=  (271, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  263  ,all data shape=  (275, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  264  ,all data shape=  (279, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  265  ,all data shape=  (283, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  266  ,all data shape=  (287, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  267  ,all data shape=  (291, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  268  ,all data shape=  (295, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  269  ,all data shape=  (299, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  270  ,all data shape=  (303, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  271  ,all data shape=  (307, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  272  ,all data shape=  (311, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  273  ,all data shape=  (315, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  274  ,all data shape=  (319, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  275  ,all data shape=  (323, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  276  ,all data shape=  (327, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  277  ,all data shape=  (331, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  278  ,all data shape=  (335, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  279  ,all data shape=  (339, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  280  ,all data shape=  (343, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  281  ,all data shape=  (347, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  282  ,all data shape=  (351, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  283  ,all data shape=  (355, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  284  ,all data shape=  (359, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  285  ,all data shape=  (363, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  286  ,all data shape=  (367, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  287  ,all data shape=  (371, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  288  ,all data shape=  (375, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  289  ,all data shape=  (379, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  290  ,all data shape=  (383, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  291  ,all data shape=  (387, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  292  ,all data shape=  (391, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  293  ,all data shape=  (395, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  294  ,all data shape=  (399, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  295  ,all data shape=  (403, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  296  ,all data shape=  (407, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  297  ,all data shape=  (411, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  298  ,all data shape=  (415, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  299  ,all data shape=  (419, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  300  ,all data shape=  (423, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  301  ,all data shape=  (427, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  302  ,all data shape=  (431, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  303  ,all data shape=  (435, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  304  ,all data shape=  (439, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  305  ,all data shape=  (443, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  306  ,all data shape=  (447, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  307  ,all data shape=  (451, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  308  ,all data shape=  (455, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  309  ,all data shape=  (459, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  310  ,all data shape=  (463, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# frame  311  ,all data shape=  (467, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# *****Exit frame counter reached
# frame  312  ,all data shape=  (471, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  313  ,all data shape=  (475, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  314  ,all data shape=  (479, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  315  ,all data shape=  (483, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  316  ,all data shape=  (487, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  317  ,all data shape=  (491, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  318  ,all data shape=  (495, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  319  ,all data shape=  (499, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  320  ,all data shape=  (503, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  321  ,all data shape=  (507, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  322  ,all data shape=  (511, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  323  ,all data shape=  (515, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  324  ,all data shape=  (519, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  325  ,all data shape=  (523, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  326  ,all data shape=  (527, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  327  ,all data shape=  (531, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# frame  328  ,all data shape=  (535, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# ** index to delete=  []
# ...
# ** index to delete=  []
# frame  647  ,all data shape=  (4481, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  648  ,all data shape=  (4485, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  649  ,all data shape=  (4489, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  650  ,all data shape=  (4493, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  651  ,all data shape=  (4497, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  652  ,all data shape=  (4501, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  653  ,all data shape=  (4505, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  654  ,all data shape=  (4509, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  655  ,all data shape=  (4513, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  656  ,all data shape=  (4517, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  657  ,all data shape=  (4521, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  658  ,all data shape=  (4525, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  659  ,all data shape=  (4529, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  660  ,all data shape=  (4533, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  661  ,all data shape=  (4537, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  662  ,all data shape=  (4541, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  663  ,all data shape=  (4545, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  664  ,all data shape=  (4549, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  665  ,all data shape=  (4553, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  666  ,all data shape=  (4557, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  667  ,all data shape=  (4561, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  668  ,all data shape=  (4565, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  669  ,all data shape=  (4569, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  670  ,all data shape=  (4573, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  671  ,all data shape=  (4577, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  672  ,all data shape=  (4581, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  673  ,all data shape=  (4585, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  674  ,all data shape=  (4589, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  675  ,all data shape=  (4593, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  676  ,all data shape=  (4597, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  677  ,all data shape=  (4601, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  678  ,all data shape=  (4605, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  679  ,all data shape=  (4609, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  680  ,all data shape=  (4613, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  681  ,all data shape=  (4617, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  682  ,all data shape=  (4621, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  683  ,all data shape=  (4625, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  684  ,all data shape=  (4629, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  685  ,all data shape=  (4633, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  686  ,all data shape=  (4637, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  687  ,all data shape=  (4641, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  688  ,all data shape=  (4645, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  689  ,all data shape=  (4649, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  690  ,all data shape=  (4653, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  691  ,all data shape=  (4657, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  692  ,all data shape=  (4661, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  693  ,all data shape=  (4665, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  694  ,all data shape=  (4669, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  695  ,all data shape=  (4673, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  696  ,all data shape=  (4677, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  697  ,all data shape=  (4681, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  698  ,all data shape=  (4685, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  699  ,all data shape=  (4689, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  700  ,all data shape=  (4693, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  701  ,all data shape=  (4697, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  702  ,all data shape=  (4701, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  703  ,all data shape=  (4705, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  704  ,all data shape=  (4709, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  705  ,all data shape=  (4713, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  706  ,all data shape=  (4717, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  707  ,all data shape=  (4721, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  708  ,all data shape=  (4725, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  709  ,all data shape=  (4729, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  710  ,all data shape=  (4733, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  711  ,all data shape=  (4737, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  712  ,all data shape=  (4741, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  713  ,all data shape=  (4745, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  714  ,all data shape=  (4749, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  715  ,all data shape=  (4753, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  716  ,all data shape=  (4757, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  717  ,all data shape=  (4761, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  718  ,all data shape=  (4765, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  719  ,all data shape=  (4769, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  720  ,all data shape=  (4773, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  721  ,all data shape=  (4777, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  722  ,all data shape=  (4781, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  723  ,all data shape=  (4785, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  724  ,all data shape=  (4789, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  725  ,all data shape=  (4793, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  726  ,all data shape=  (4797, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  727  ,all data shape=  (4801, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  728  ,all data shape=  (4805, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  729  ,all data shape=  (4809, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  730  ,all data shape=  (4813, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  731  ,all data shape=  (4817, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  732  ,all data shape=  (4821, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  733  ,all data shape=  (4825, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  734  ,all data shape=  (4829, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  735  ,all data shape=  (4833, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  736  ,all data shape=  (4837, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  737  ,all data shape=  (4841, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  738  ,all data shape=  (4845, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  739  ,all data shape=  (4849, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  740  ,all data shape=  (4853, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  741  ,all data shape=  (4857, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  742  ,all data shape=  (4861, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  743  ,all data shape=  (4865, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  744  ,all data shape=  (4869, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  745  ,all data shape=  (4873, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  746  ,all data shape=  (4877, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  747  ,all data shape=  (4881, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  748  ,all data shape=  (4885, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  749  ,all data shape=  (4889, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  750  ,all data shape=  (4893, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  751  ,all data shape=  (4897, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  752  ,all data shape=  (4901, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  753  ,all data shape=  (4905, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  754  ,all data shape=  (4909, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  755  ,all data shape=  (4913, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  756  ,all data shape=  (4917, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  757  ,all data shape=  (4921, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  758  ,all data shape=  (4925, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  759  ,all data shape=  (4929, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  760  ,all data shape=  (4933, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  761  ,all data shape=  (4937, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  762  ,all data shape=  (4941, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  763  ,all data shape=  (4945, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  764  ,all data shape=  (4949, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  765  ,all data shape=  (4953, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  766  ,all data shape=  (4957, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  767  ,all data shape=  (4961, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  768  ,all data shape=  (4965, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  769  ,all data shape=  (4969, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  770  ,all data shape=  (4973, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  771  ,all data shape=  (4977, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  772  ,all data shape=  (4981, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  773  ,all data shape=  (4985, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  774  ,all data shape=  (4989, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  775  ,all data shape=  (4993, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  776  ,all data shape=  (4997, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  777  ,all data shape=  (5001, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  778  ,all data shape=  (5005, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  779  ,all data shape=  (5009, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  780  ,all data shape=  (5013, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  781  ,all data shape=  (5017, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  782  ,all data shape=  (5021, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  783  ,all data shape=  (5025, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  784  ,all data shape=  (5029, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  785  ,all data shape=  (5033, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  786  ,all data shape=  (5037, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  787  ,all data shape=  (5041, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  788  ,all data shape=  (5045, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  789  ,all data shape=  (5049, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  790  ,all data shape=  (5053, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  791  ,all data shape=  (5057, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  792  ,all data shape=  (5061, 17)
# Person present  4
# ** index to delete=  []
# ** index to delete=  []
# frame  793  ,all data shape=  (5065, 17)
# Person present  4
