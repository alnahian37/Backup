# %%
import json
import time
import pickle
import kinectpy as kpy
import ast
from kinectpy.k4a._k4atypes import K4A_CALIBRATION_TYPE_DEPTH
import gc




import scipy.io
import numpy as np
import csv
import copy

from scipy.optimize import linear_sum_assignment

import os
import csv

import pickle
import json
import ast

import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from math import inf

import sys
sys.path.insert(1, './../')

from timeit import repeat

import kinectpy as kpy
from kinectpy.k4abt._k4abtTypes import K4ABT_SEGMENT_PAIRS
from kinectpy.k4abt import _k4abt
from kinectpy.k4a import _k4a
from kinectpy.k4a._k4atypes import K4A_CALIBRATION_TYPE_DEPTH, K4A_CALIBRATION_TYPE_COLOR
import logging
from matplotlib import animation
import time
from datetime import datetime
import scipy.io
import time
import socket
from _thread import *



all_indexes=range(60)
#Table
x1=np.linspace(2090,3115,3)
z1=np.linspace(0,740,3)
y1=np.linspace(1570,8850,3)
x1=np.array(x1).reshape(len(x1),1)
y1=np.array(y1).reshape(len(y1),1)
z1=np.array(z1).reshape(len(z1),1)
x,y=np.meshgrid(x1,y1)
z=737*np.ones((len(x1),len(y1)))
z_floor=np.zeros((len(x1),len(y1)))
xx,zz=np.meshgrid(x1,z1)
yy=1570*np.ones((len(x1),len(z1)))
yy2=8850*np.ones((len(x1),len(z1)))
x2=np.linspace(0,4500,3)
z2=np.linspace(0,3000,3)
y2=np.linspace(0,10000,3)
x2=np.array(x2).reshape(len(x2),1)
y2=np.array(y2).reshape(len(y2),1)
z2=np.array(z2).reshape(len(z2),1)
x_floor,y_floor=np.meshgrid(x2,y2)
z_floor=np.zeros((len(x2),len(y2)))
xxx,zzz=np.meshgrid(x2,z2)
yyy=np.zeros((len(x2),len(z2)))
y3,z3=np.meshgrid(y2,z2)
x3=4500*np.ones((len(y2),len(z2)))
y4,z4=np.meshgrid(y2,z2)
x4=np.zeros((len(y2),len(z2)))
y5=10000*np.ones((len(x2),len(z2)))
z2=np.linspace(0,2000,3)
y2=np.linspace(8200,9000,3)
y2=np.array(y2).reshape(len(y2),1)
z2=np.array(z2).reshape(len(z2),1)
y6,z6=np.meshgrid(y2,z2)
x6=np.zeros((len(y2),len(z2)))


def initialize_plots():
    fig = plt.figure(figsize=(10, 10),dpi=200)

    # Create axis
    axes = fig.add_subplot(111, projection='3d')  
    #axes.set_aspect('auto') 
    (x_min, x_max), (y_min, y_max), (z_min, z_max) = ((0, 4500), (0,10400), (0, 3000)) 
   
    #Door
    axes.plot_surface(x6, y6, z6, color='k',alpha=1,edgecolor=None)

    #Wall
    axes.plot_surface(xxx,y5,zzz,alpha=0.5,color='green',edgecolor=None)
    axes.plot_surface(x4,y4,z4,alpha=0.5,color='blue',edgecolor=None)
    axes.plot_surface(x3,y3,z3,alpha=0.5,color='blue',edgecolor=None)
    axes.plot_surface(xxx,yyy,zzz,alpha=0.5,color='green',edgecolor=None)    
    #Table
    axes.plot_surface(xx,yy,zz,color='magenta',alpha=0.5,edgecolor=None)
    axes.plot_surface(xx,yy2,zz,color='magenta',alpha=0.5,edgecolor=None)
    axes.plot_surface(x,y,z,color='magenta',alpha=0.3,edgecolor=None)
    axes.plot_surface(x_floor,y_floor,z_floor,color='blue',alpha=0.2,edgecolor=None)    
    
    axes.set_xlabel('X')
    axes.set_ylabel('Y')
    axes.set_zlabel('Z')
    axes.set_xlim(left=x_min, right=x_max)
    axes.set_ylim(bottom=y_min, top=y_max)
    axes.set_zlim(bottom=z_min, top=z_max)
    axes.axis('off')
    #axes.grid(True)
    #axes.set_axis_off()
    axes.view_init(azim = -115, elev = 35)
    axes.w_zaxis.set_pane_color((0, 1, 0, 0.2))
    axes.get_proj = lambda: np.dot(Axes3D.get_proj(axes), np.diag([0.5, 1, 0.3, 1]))
    plots = {index: axes.plot([0], [0], [0], 'bo-', markersize = 0)[0] for index in all_indexes}

    return fig, axes, plots


#Load the calibrated parameters
p4=scipy.io.loadmat('new_cam4_params_umeyama.mat')['name']
W4=p4[0:3,:]
b4=p4[3:,:]

p3=scipy.io.loadmat('new_cam3_params_umeyama.mat')['name']
W3=p3[0:3,:]
b3=p3[3:,:]

p2=scipy.io.loadmat('new_cam2_params_umeyama.mat')['name']
W2=p2[0:3,:]
b2=p2[3:,:]

p1=scipy.io.loadmat('new_cam1_params_umeyama.mat')['name']
W1=p1[0:3,:]
b1=p1[3:,:]

#Detect Current Frame Activity
def activity_detection(cur_frame):    
    if (sum(cur_frame[:,3])==0):
        #print('No activity detected')
        activ=np.zeros((cur_frame.shape[0],1))
        activ[:]=4 #no activity when no person is present and only zeros are sent here
        return activ
    
    poses=(cur_frame[:,3]>1300).astype(int).reshape(cur_frame.shape[0],1)
    
    activ=copy.deepcopy(poses)    

    ##Activity 1: Random
    if sum(poses)==cur_frame.shape[0]: #All standing        
        activ[:]=1

    ##Activity 2: Table
    elif sum(poses)==0: #All sitting
        activ[:]=2
    
    ##Activity 3: Presentation or Activity 2: Table or Activity 1: Random
    elif sum(poses)>0 and sum(poses)<cur_frame.shape[0]: #Some standing, some sitting
        y_values=np.zeros((cur_frame.shape[0],1))
        x_values=np.zeros((cur_frame.shape[0],1))
        z_values=np.zeros((cur_frame.shape[0],1))
        flag_presentation=0
        
        
        if sum(poses)<=0.5*cur_frame.shape[0]: #Most people sitting
            for j in range(cur_frame.shape[0]):
                y_values[j]=cur_frame[j,2]
                x_values[j]=cur_frame[j,1]
                z_values[j]=cur_frame[j,3]

            for j in range(cur_frame.shape[0]):
                if y_values[j]>8650 and x_values[j]>1850 and x_values[j]<4200 and z_values[j]>1300: # Presenter is standing, most people sitting
                    flag_presentation=+1
        if flag_presentation>0:
            ######print("PRESENTATION")  ##Activity 3: Presentation
            activ[:]=3
            #flag_presentation=0
        else:
            ######print("Random Standing")
            if (sum(poses)>0.5*cur_frame.shape[0]): #More people standing
                activ[:]=1 #Random
            else:
                activ[:]=2 #Table for majority sitting
    ######print("activ ",activ)
    activ=np.reshape(activ,(cur_frame.shape[0],1))
    global temporal_activ

    temporal_activ[:len(temporal_activ)-1]=temporal_activ[1:]
    temporal_activ[-1]=activ[0,0]
    activ[:]=int(st.mode(temporal_activ)) #mode of the last n seconds. so, activity needs to be stable for n/2 seconds to be valid
    
    return activ

def convert_to_unity(cur_frame):
    unity_data=np.zeros((cur_frame.shape[0],11))

    unity_data[:,0]=cur_frame[:,0]
    unity_data[:,1]=np.round(cur_frame[:,1]/1000,2)-5.1*(cur_frame[:,1]>0)-(cur_frame[:,1]==0)*10  #unity x
    unity_data[:,2]=((cur_frame[:,3]>1300).astype(float)*0.5+1)*(cur_frame[:,3]>0).astype(int) #unity y
    unity_data[:,3]=np.round(cur_frame[:,2]/1000,2)-10.8*(cur_frame[:,2]>0) #unity z
    unity_data[:,4]=cur_frame[:,11]
    unity_data[:,5]=cur_frame[:,13]
    unity_data[:,6]=cur_frame[:,12]
    unity_data[:,7]=cur_frame[:,15].astype(int) #activity
    unity_data[:,8]=(cur_frame[:,3]>1300).astype(int)+1 #pose
    unity_data[:,9]=cur_frame[:,16].astype(int) #sTAtionary
    unity_data[:,10]=0 #glare
    
    return unity_data
def send_to_unity(unity_data):
    data=unity_data[:,1:].reshape(-1)
    send_string='$'.join(map(str, data))
    send_string='Avatar$'+send_string
    return send_string

def get_camera_data(num_bodies4,bodyFrame4,W1,b1):
    cam4s=[]
    for body_id in range(num_bodies4):

        body3d4 = bodyFrame4.get_body3d(body_id, dest_camera = K4A_CALIBRATION_TYPE_DEPTH)
    
        all_joints4=[]
        for joint in body3d4.joints:

            join=joint.get_coordinates()
            #if join[2]>far_threshold:
                #far_flag=1
                
            join=join@W1.T+b1
            join.reshape(3,1)
            con=np.array([joint.confidence_level]).reshape(1,1)
            join_con=np.concatenate((join,con),axis=1)
            all_joints4.append(join_con)
        all_joints4=np.array(all_joints4).reshape(32,4)
        nose_pos=all_joints4[27,0:3]
        tmp=copy.deepcopy(nose_pos)
        nose_pos[1]=tmp[2]
        nose_pos[2]=tmp[1]
        nose_pos[1]=room_length-nose_pos[1]
        
        confidence=np.mean(all_joints4[:,3])
        ear_left=all_joints4[29,0:3]
        tmp=copy.deepcopy(ear_left)
        ear_left[1]=tmp[2]
        ear_left[2]=tmp[1]
        ear_left[1]=room_length-ear_left[1]

        ear_right=all_joints4[31,0:3]
        tmp=copy.deepcopy(ear_right)
        ear_right[1]=tmp[2]
        ear_right[2]=tmp[1]
        ear_right[1]=room_length-ear_right[1]

        
        p1=(ear_left+ear_right)/2
        v=nose_pos-p1 
        p2=500*v / np.linalg.norm(v)+p1 ## 10*front_point-9*back_point
        position_vector=p2-p1
        
        #if nose_pos[1]>z_threshold: # y distance from origin
        
        if 0==0:
            cam4=np.concatenate((np.array([frame]),nose_pos,np.array([confidence]),p1,p2,position_vector))
            cam4s.append(cam4)
            #necks4.append(neck)
        else:
            #far_flag=0
            num_bodies4-=1
        
    if num_bodies4>0:
        cam4s=np.array(cam4s)
        del_idx=np.where(cam4s[:,1]<0)[0]
        #print("** index to delete= ",del_idx,"")
    #del_idx=np.where(prev_frame_data[:,-3]==unique_ids[ind])[0]
        cam4s=np.delete(cam4s,del_idx,0)
    return cam4s



#END of Function Declarations above

#print("enter 1 for online and 2 for offline")
#on_off=int(input())

# Initialize the library, if the library is not found, add the library path as argument
kpy.initialize_libraries(track_body=True)





fig, axes, plots = initialize_plots()    

plt.ion()

def showing_plot(plot_data):
    poin1s=[]
    poin2s=[]
    poin3s=[]
    poin4s=[]
    for i in range(plot_data.shape[0]):
        x1=plot_data[i][5]
        y1=plot_data[i][6]
        z1=plot_data[i][7]
        x2=plot_data[i][8]
        y2=plot_data[i][9]
        z2=plot_data[i][10]

        poin1=np.array([x1,y1,z1])
        poin2=np.array([x2,y2,z2])
        poin3=np.array([x1,y1,0])
        poin1s.append(poin1)
        poin2s.append(poin2)
        poin3s.append(poin3)
        poin4s.append(plot_data[i][16])
    for l in range(len(all_indexes)):
        plots[l].set_xdata(np.asarray(0))
        plots[l].set_ydata(np.asarray(0))
        plots[l].set_3d_properties(np.asarray(0))
    
    poin1s=np.array(poin1s)
    poin2s=np.array(poin2s)
    poin3s=np.array(poin3s)
    poin4s=np.array(poin4s)
    for i in range(poin1s.shape[0]):
        if i==0:
            color = ((1, 0, 0))
        elif i==1:
            color = ((0, 1, 0))
        elif i==2:
            color = ((0, 0, 1))
        elif i==3:
            color = ((1, 1, 0))
        elif i==4:
            color = ((1, 0, 1))
        elif i==5:
            color = ((0, 1, 1))
        elif i==6:
            color = ((0.75, 0.75, 0.75))
        elif i==7:
            color = ((0.5, 0, 0))
        elif i==8:
            color = ((0, 0.5, 0))
        elif i==9:
            color = ((0, 0, 0.5))
        elif i==10:
            color = ((0.5, 0.5, 0))
        elif i==11:
            color = ((0.5, 0, 0.5))
        elif i==12:
            color = ((0, 0.5, 0.5))
        elif i==13:
            color = ((0.5, 0.5, 0.5))

        p1=poin1s[i]
        p2=poin2s[i]
        p3=poin3s[i]
        p4=poin4s[i]
        plots[i].set_xdata(np.asarray((p2[0],p1[0])))
        plots[i].set_ydata(np.asarray((p2[1],p1[1])))
        plots[i].set_3d_properties(np.asarray((p2[2],p1[2])))
        plots[i].set_markersize(2)
        plots[i].set_color(color)
        plots[i+25].set_xdata(np.asarray((p1[0])))
        plots[i+25].set_ydata(np.asarray((p1[1])))
        plots[i+25].set_3d_properties(np.asarray((p1[2])))
    
        if p1[2]>1300 or p1[2]==0:
            if p4==1:
                plots[i+25].set_color((1,0,0))
            else:

                plots[i+25].set_color((0,0,0))
        elif p1[2]<=1300:
            if p4==1:
                plots[i+25].set_color((1,0,0))
            else:
                plots[i+25].set_color((0.1,0.9,0.1))
        #plots[i+15].set_color((0,0,0))
        plots[i+25].set_markersize(5)
        plots[i+40].set_xdata(np.asarray((p3[0],p1[0])))
        plots[i+40].set_ydata(np.asarray((p3[1],p1[1])))
        plots[i+40].set_3d_properties(np.asarray((p3[2],p1[2])))
        plots[i+40].set_markersize(2)
        if p1[2]>1300 or p1[2]==0:
            plots[i+40].set_color((0,0,0))
        elif p1[2]<=1300:# and p1[2]!=0:
            plots[i+40].set_color((0.1,0.9,0.1))
    fig.canvas.draw()
    plt.pause(0.001)
    #txt="\n\nFrame {}\n".format(frame) #default
    txt=''
    txt2=''
    if plot_data[0][-2]==1:
        txt2='default'
    elif plot_data[0][-2]==2:
        txt2='table'
    elif plot_data[0][-2]==3:
        txt2='presentations'
    elif plot_data[0][-2]==4:
        txt2='no activity'
    txt=txt+txt2         
    axes.title.set_text(txt)
    axes.title.set_fontsize(10)


frame=0
flag_enter=0
flag_exit=0
this_frame_exit=0



prev_frame_enter=1
prev_frame_exit=1

data_col=17
data_col_less=14

prev_frame_data=np.array([]).reshape(-1,data_col_less)
#prev_neck_data=np.array([]).reshape(-1,3)
all_data=np.array([]).reshape(-1,data_col)

flag2=0

smooth_window=0


#FOr Person ID

latest_person_id=0
person_id_list=np.array([]).reshape(-1,1)
far_threshold=6500
same_threshold=500

entering_frame=[]

room_length=11000






print("enter number")
person_present=int(input())
print("where to show? 1 for python and 0 for unity and 2 for none")
plot_flag=int(input())
send_to_unity_flag=not plot_flag

if  send_to_unity_flag:
    host, port = "127.0.0.1",65432
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    sock.connect((host, port))

T=time.time()

if plot_flag==1:
    fps=5
elif plot_flag and plot_flag!=1:
    fps=10

fps=15


file_number=1
dtime=datetime.now()
dtime = dtime.strftime("%d_%m_%Y %H_%M_%S")
#dtime=dtime[:-10]
direc=os.getcwd()
direc=os.path.join(direc,'data collected')

path=os.path.join(direc,dtime)

frame_total=80*fps #default 300 seconds
remember_time=60 #How many previous seconds to remember for saving. Make it less than frame_total seconds
total_files_to_save=1000

close_to_door=[]
exit_event_frame=-remember_time*fps
enter_event_frame=-remember_time*fps
exit_frame_counter=0


os.mkdir(path)


gc.enable()





video_path=r'D:\Video Data\Video Feb 2 Backup'


all_videos=os.listdir(video_path)
print(all_videos[0],all_videos[-1])

temporal_activ=4*np.ones(6*fps) #No activity initialization


for enum,video in enumerate(all_videos):

    video_path=os.path.join(video_path,video)
    print("Processing Video= ",video_path)
    time.sleep(1)

    #video1_filename=r"D:\Kinect Tools\Nahian\Code Backup Mar 29\All_code_f\Neo kinect calibration\New Calibration\video jan19\jan4.mkv"
    #video2_filename=r"D:\Kinect Tools\Nahian\Code Backup Mar 29\All_code_f\Neo kinect calibration\New Calibration\video jan19\jan3.mkv"
    #video3_filename=r"D:\Kinect Tools\Nahian\Code Backup Mar 29\All_code_f\Neo kinect calibration\New Calibration\video jan19\jan2.mkv"
    #video4_filename=r"D:\Kinect Tools\Nahian\Code Backup Mar 29\All_code_f\Neo kinect calibration\New Calibration\video jan19\jan1.mkv"
    video1_filename=video_path+r"\output"+str(enum+1)+"_1.mkv"
    video2_filename=video_path+r"\output"+str(enum+1)+"_2.mkv"
    video3_filename=video_path+r"\output"+str(enum+1)+"_3.mkv"
    video4_filename=video_path+r"\output"+str(enum+1)+"_4.mkv"


    print(video1_filename)

    playback1 = kpy.start_playback(video1_filename)
    playback2 = kpy.start_playback(video2_filename)
    playback3 = kpy.start_playback(video3_filename)
    playback4 = kpy.start_playback(video4_filename)

    playback_config1 = playback1.get_record_configuration()
    playback_calibration1 = playback1.get_calibration()
    playback_config2 = playback2.get_record_configuration()
    playback_calibration2 = playback2.get_calibration()
    playback_config3 = playback3.get_record_configuration()
    playback_calibration3 = playback3.get_calibration()
    playback_config4 = playback4.get_record_configuration()
    playback_calibration4 = playback4.get_calibration()



    bodyTracker1 = kpy.start_body_tracker(calibration=playback_calibration1)
    bodyTracker2 = kpy.start_body_tracker(calibration=playback_calibration2)
    bodyTracker3 = kpy.start_body_tracker(calibration=playback3.calibration)
    bodyTracker4 = kpy.start_body_tracker(calibration=playback4.calibration)


    while playback1.isOpened() and playback2.isOpened() and playback3.isOpened() and playback4.isOpened():

        print("frame ",frame," ,all data shape= ",all_data.shape)
        
        print("Person present ",person_present)
        #print("frame",frame)
        if file_number==total_files_to_save+1:
            break
        elap=time.time()-T  
        T=time.time()
        

        if frame==frame_total:# and person_present:
            if all_data.shape[0]:
                take_index_from=np.int32(np.max((all_data[0,0],frame-remember_time*fps)))
                print(" Take index FROM ",take_index_from)
                #take_index=np.min(np.where(all_data[:,0]==take_index_from)[0])
                take_index=np.where(all_data[:,0]==take_index_from)[0]
                
                if take_index.shape[0]:
                    temporary_all=copy.deepcopy(all_data[take_index[0]:,:])
                else:                
                    temporary_all=np.array([]).reshape(-1,data_col)
            
                all_data=copy.deepcopy(temporary_all)
                if np.mean(np.abs(all_data[:,1])):
                #if all_data.shape[0]:
                    filename=path+'/'+f'{file_number:05d}'+'.npy'
                    np.save(filename,all_data)
                    print("     saving")
                    file_number+=1
                else:
                    print("    Not SAVING")
                all_data[:,0]-=remember_time*fps
                #print("HAHA ",all_data[0,0])
                entering_frame=[max((x-remember_time*fps),1) for x in entering_frame]#-10*fps
                print(entering_frame)
                prev_frame_enter=max(prev_frame_enter- remember_time*fps,1)
                prev_frame_exit=max(prev_frame_exit-remember_time*fps,1)
            frame-=remember_time*fps
            exit_event_frame=np.max((exit_event_frame-remember_time*fps,-remember_time*fps))
            #gc.collect()

            
            

        
        if all_data.shape[0]>0 and person_present>0:
            recent_frame_data=np.where(all_data[:,0]==all_data[-1,0])[0]
            if recent_frame_data.shape[0]>0:
                plot_data=all_data[recent_frame_data,:]
                unity_data=convert_to_unity(plot_data)
                #print("unity_data= ",unity_data[:,1:10])
                if plot_flag==1:
                    showing_plot(plot_data)
                if send_to_unity_flag:
                    data_string=send_to_unity(unity_data)
                    print("data_string= ",data_string[:20])
                    T1=time.time()
                    sock.sendall(data_string.encode("UTF-8"))
                    receivedData = sock.recv(1024).decode("UTF-8")
                    elap=1000*(time.time()-T1)
                    print("Socekt comm takes miliseconds", elap)
                    print(receivedData)
        if person_present==0 and plot_flag==1:
            plot_data=np.zeros((1,data_col))
            showing_plot(plot_data)

            
        frame+=1
        if frame==exit_event_frame+1 and flag_exit==1:
            close_to_door=[]
            exit_frame_counter=0

        if frame==1 and person_present:
            ######print("  frame: ",frame, "person_present: ",person_present)
            for i in range(person_present):
                person_id_list=np.vstack((person_id_list,i+1))
                entering_frame.append(frame)
            prev_frame_data=np.zeros((person_present,data_col_less))
            prev_frame_data[:,0]=frame
            prev_frame_data=np.hstack((prev_frame_data,person_id_list))
            all_data=np.zeros((person_present,data_col))
            all_data[:,0]=frame
            all_data[:,-3]=person_id_list.reshape(-1)
            latest_person_id=person_present
            activ=activity_detection(prev_frame_data)
            ######print("\n\n activ: ",activ,"\n\n")
            all_data[:,-2]=activ.reshape(-1)
            
            continue

        
        time_start = time.time()

        if 1==2:
            playback1.update()
            playback1.update()
            playback2.update()
            playback2.update()
            playback3.update()
            playback3.update()
            playback4.update()
            playback4.update()

        capture1 = playback1.update()
        ret1,img=capture1.get_ir_image()
        if ret1==False:
            continue
        bodyFrame1 = bodyTracker1.update(capture=capture1)

        
        capture2 = playback2.update()
        ret2,img=capture2.get_ir_image()
        if ret2==False:
            continue
        bodyFrame2 = bodyTracker2.update(capture=capture2)

    
        capture3 = playback3.update()
        ret3,img=capture3.get_ir_image()
        if ret3==False:
            continue
        bodyFrame3 = bodyTracker3.update(capture=capture3)

        
        capture4 = playback4.update()
        ret4,img=capture4.get_ir_image()
        if ret4==False:
            continue
        bodyFrame4 = bodyTracker4.update(capture=capture4)

        num_bodies1 = bodyFrame1.get_num_bodies()   
        num_bodies2 = bodyFrame2.get_num_bodies()    
        num_bodies3 = bodyFrame3.get_num_bodies()
        num_bodies4 = bodyFrame4.get_num_bodies()
        



        cam1s=[]
        cam2s=[]
        cam3s=[]
        cam4s=[]   


        if num_bodies1 > 0:
            far_flag=0
            cam1s=get_camera_data(num_bodies1,bodyFrame1,W4,b4)
            
        if num_bodies2 > 0:
            far_flag=0
            cam2s=get_camera_data(num_bodies2,bodyFrame2,W3,b3)
        
            
        if num_bodies3 > 0:
            far_flag=0
            cam3s=get_camera_data(num_bodies3,bodyFrame3,W2,b2) 
        
        
        if num_bodies4 > 0:
            far_flag=0
            cam4s=get_camera_data(num_bodies4,bodyFrame4,W1,b1)
            

            #Predicts Entry
            close_noses=np.array([]).reshape(-1,3)
            for noses in cam4s:
                nose=noses[1:4].reshape(1,3)[0]
                if nose[0]<900 and nose[0]>-100 and nose[1]>9000 and nose[1]<room_length:
                    close_noses=np.concatenate((close_noses,nose.reshape(1,3)),axis=0)
            if close_noses.shape[0]>0: #Possible Entry Event
                print("****WE HAVE A POSSIBLE ENTRY EVENT")
                if person_present==0:
                    person_present+=close_noses.shape[0]
                    prev_frame_enter=frame
                    
                    flag_enter=1
                    for nose in close_noses:
                        nose_enter=nose
                        print("Person entered")
                        print("Nose position: ",nose_enter)

                        latest_person_id+=1
                        person_id_list=np.vstack((person_id_list,latest_person_id))
                        #person_id_list.append(latest_person_id)
                        entering_frame.append(frame)

                        prev_frame_data=np.vstack((prev_frame_data,np.zeros(prev_frame_data.shape[1])))
                        prev_frame_data[-1,1:4]=nose_enter
                        prev_frame_data[-1,5:8]=[500,8500,1500]
                    flag_enter=0

                else: #Previous person/ persons already present
                    print("")
                    for nose in close_noses:

                        indices=np.where(all_data[:,0]==all_data[-1,0])[0]

                        data_taken=all_data[indices,:]
                        #print("   Enter flag on and data taken shape=",data_taken.shape)
                        

                        dist_enter=np.zeros(data_taken.shape[0])
                        for i in range(data_taken.shape[0]):
                            #dist_exit[i]=np.linalg.norm(prev_frame_data[i,1:4]-nose_exit)
                            dist_enter[i]=np.linalg.norm(data_taken[i,1:4]-nose)
                            print("  Enter Distances: ",dist_enter, "for ID: ",data_taken[i,-3])

                        lowest_dist=np.min(dist_enter)
                        if lowest_dist>550:
                            print("  ### New person entered")
                            print("## Enter distance: ",lowest_dist)
                            print("## Entering Nose position: ",nose)
                            latest_person_id+=1
                            person_present+=1
                            person_id_list=np.vstack((person_id_list,latest_person_id))
                            #person_id_list.append(latest_person_id)
                            entering_frame.append(frame)
                            prev_frame_data=np.vstack((prev_frame_data,np.zeros(prev_frame_data.shape[1])))
                            prev_frame_data[-1,1:4]=nose
                            prev_frame_data[-1,5:8]=[500,8500,1500]

            
        
            for noses in cam4s: #Exit Prediction
                nose=noses[1:4].reshape(1,3)[0]
                p1=noses[5:8].reshape(1,3)[0]
                posvect=nose-p1
                posvect=posvect.reshape((1,3))

                posvect2=np.array([posvect[0,0],posvect[0,1]]).reshape(1,2)        


                #angle=np.arccos(np.dot(posvect,np.array([1,0,0]))/(np.linalg.norm(posvect)*np.linalg.norm(np.array([1,0,0]))))[0]
                angle=np.arccos(np.dot(posvect2,np.array([1,0]))/(np.linalg.norm(posvect2)*np.linalg.norm(np.array([1,0]))))[0]
                a=angle*180/np.pi


                #Exit  
                if 180/np.pi*angle>110 and nose[0]<1000 and nose[0]>-100 and nose[1]>9500 and nose[1]<room_length:
                    #if frame-prev_frame_exit>fps and frame-prev_frame_enter>fps:
                    if 1==1:   
                        nose_exit=nose
                        
                        flag_exit=1
                        exit_event_frame=frame
                        print("EXIT PREDICTED AT FRAME ",frame," WITH ANGLE ",a)

            
        
        frame_data=np.array([]).reshape(-1,data_col_less)
        temporary_frame_data=np.array([]).reshape(-1,data_col_less)
        
        
        if num_bodies1==0 and num_bodies2==0 and num_bodies3==0 and num_bodies4==0: #Either no person present or dropout by kinects
            ######print('no body')
            if person_id_list.shape[0]: #Means person present but dropped out
                
            
                frame_data=copy.deepcopy(prev_frame_data)
            
                frame_data[:,0]=frame
                prev_frame_data=copy.deepcopy(frame_data) #For next frame
        
                frame_data2=np.hstack((frame_data,np.zeros((frame_data.shape[0],2))))
                activ=activity_detection(frame_data)
                frame_data2[:,-2]=activ.reshape(-1)
                all_data=np.vstack((all_data,frame_data2))

                #To check if person is standing still
                if frame>2*fps:
                    for m in range(person_id_list.shape[0]):
                        if frame-entering_frame[m]>2*fps:
                            considered_indices=np.where(all_data[:,0]==frame-2*fps)[0]
                            ######print("CONsidered_indices ",considered_indices)
                            for n in considered_indices:
                                if all_data[n,-3]==person_id_list[m]:
                                    considered_indices2=n
                            
                            cons_data=copy.deepcopy(all_data[considered_indices2,1:4])
                            considered_positions=cons_data #np.mean(cons_data,axis=0)
                            current_indices=np.where(all_data[:,0]==frame)[0]
                            for n in current_indices:
                                if all_data[n,-3]==person_id_list[m]:
                                    current_indices2=n
                            ######print("CURrent_indices2 ",current_indices2)
                            cur_dat=copy.deepcopy(all_data[current_indices2,1:4])
                            current_positions=cur_dat
                        
                            if np.linalg.norm(considered_positions-current_positions)<1000: #1 meter
                                frame_data2[m,-1]=1
                                all_data[current_indices2,-1]=1
                                
            


            if flag_exit==1 and frame>exit_event_frame+1:
                indices=np.where(all_data[:,0]==all_data[-1,0])[0]
                indices_prev=np.where(all_data[:,0]==all_data[-1,0]-1)[0]
                data_taken=all_data[indices,:]
                data_taken_prev=all_data[indices_prev,:]
                if data_taken.shape[0]>data_taken_prev.shape[0]:
                    data_taken_prev=np.vstack((data_taken_prev,np.zeros((data_taken.shape[0]-data_taken_prev.shape[0],data_taken_prev.shape[1]))))
                #print("   Exit flag on and data taken shape=",data_taken.shape)
                

                dist_exit=np.zeros(data_taken.shape[0])
                data_exit=np.zeros((data_taken.shape[0],2))
                
                for i in range(data_taken.shape[0]):
                    if data_taken[i,1]<1800 and data_taken[i,2]>8500:
                        dist_exit[i]=np.linalg.norm(data_taken[i,1:3]-data_taken_prev[i,1:3])+1
                        print("Temp data taken= ",data_taken[i,1:3],"")
                        print("Temp Exit distance= ",dist_exit[i],"  ID= ",data_taken[i,-3],"")
                        if dist_exit[i]==1:
                            close_to_door.append(data_taken[i,-3]) #Take the person ID
                            print(" AAdding to close to door distance= ",dist_exit[i], "  ID= ",data_taken[i,-3])
                        else:
                            print("  Not adding still")


                    
                    
                    
                #print("         DISTANCE=,",dist_exit)
                exit_frame_counter+=1

                if exit_frame_counter==10*fps:
                    print("*****Exit frame counter reached")
                    print(" **Close to door list length= ",len(close_to_door))
                    exit_frame_counter=0
                    flag_exit=0
                    unique_ids=np.unique(close_to_door)
                    unique_ids.sort()
                    unique_ids=unique_ids[::-1]
                    for ind in range(len(unique_ids)):
                        print("****close to door count=",close_to_door.count(unique_ids[ind]),"  ID= ",unique_ids[ind])
                        if close_to_door.count(unique_ids[ind])>3*fps:
                            print("**Deleting person ID= ",unique_ids[ind])
                            del_idx=np.where(data_taken[:,-3]==unique_ids[ind])[0]
                            print("** index to delete= ",del_idx,"")
                            #del_idx=np.where(prev_frame_data[:,-3]==unique_ids[ind])[0]
                            prev_frame_data=np.delete(prev_frame_data,del_idx,0)
                            person_id_list=np.delete(person_id_list,del_idx,0)
                    close_to_door=[]
                    person_present=prev_frame_data.shape[0]
                    print(" **Person present after deleting= ",person_present)
            continue
        else:
            if num_bodies1>0:
                temporary_frame_data=np.vstack((temporary_frame_data,cam1s))
                
            if num_bodies2>0:
                temporary_frame_data=np.vstack((temporary_frame_data,cam2s))
                
            if num_bodies3>0:
                temporary_frame_data=np.vstack((temporary_frame_data,cam3s))
                
            if num_bodies4>0:
                temporary_frame_data=np.vstack((temporary_frame_data,cam4s))
                
            
            #The following few lines are to remove the same person detected by different cameras
            allidx=np.array(list(range(temporary_frame_data.shape[0])))
            for k in range(temporary_frame_data.shape[0]):
                same=[]
                if k in allidx:
                    for l in range(k+1,temporary_frame_data.shape[0]):                        
                        if np.abs(np.linalg.norm(temporary_frame_data[k,1:3]-temporary_frame_data[l,1:3]))<same_threshold:# or np.abs(np.linalg.norm(temporary_neck_data[k,:]-temporary_neck_data[l,:]))<600:
                            same.append(l)
                            same.append(k)
                
                    same=np.unique(same).reshape(-1)
                    if list(same)==[]:
                        frame_data=np.vstack((frame_data,temporary_frame_data[k,:]))
                        
                    else:
                        confidences=temporary_frame_data[same,4]
                        max_confidence=np.argmax(confidences)
                        frame_data=np.vstack((frame_data,temporary_frame_data[same[max_confidence],:]))
                        allidx=[x for x in allidx if x not in same]                
  

        

        
        
        #if frame==exit_event_frame and flag_exit==1:
        #    close_to_door=[]
        #    exit_frame_counter=0

        if flag_exit==1 and frame>exit_event_frame+1 and person_present:
            indices=np.where(all_data[:,0]==all_data[-1,0])[0]
            indices_prev=np.where(all_data[:,0]==all_data[-1,0]-1)[0]
            data_taken=all_data[indices,:]
            data_taken_prev=all_data[indices_prev,:]
            if data_taken.shape[0]>data_taken_prev.shape[0]:
                    data_taken_prev=np.vstack((data_taken_prev,np.zeros((data_taken.shape[0]-data_taken_prev.shape[0],data_taken_prev.shape[1]))))
            print("   Exit flag on and data taken shape=",data_taken.shape,"  prev frame data shape= ",data_taken_prev.shape)
            

            dist_exit=np.zeros(data_taken.shape[0])
            data_exit=np.zeros((data_taken.shape[0],2))
            
            for i in range(data_taken.shape[0]):
                if data_taken[i,1]<1800 and data_taken[i,2]>8500:
                    dist_exit[i]=np.linalg.norm(data_taken[i,1:3]-data_taken_prev[i,1:3])+1
                    print("Temp data taken= ",data_taken[i,1:3],"")
                    print("Temp Exit distance= ",dist_exit[i],"  ID= ",data_taken[i,-3],"")
                    if dist_exit[i]==1:
                        close_to_door.append(data_taken[i,-3]) #Take the person ID
                        print(" AAdding to close to door distance= ",dist_exit[i], "  ID= ",data_taken[i,-3])
                    else:
                        print("  Not adding still")
            exit_frame_counter+=1

            if exit_frame_counter==10*fps:
                print("*****Exit frame counter reached")
                exit_frame_counter=0
                flag_exit=0
                unique_ids=np.unique(close_to_door)
                unique_ids.sort()
                unique_ids=unique_ids[::-1]
                for ind in range(len(unique_ids)):
                    print("****close to door count=",close_to_door.count(unique_ids[ind]),"  ID= ",unique_ids[ind])
                    if close_to_door.count(unique_ids[ind])>3*fps:
                        print("**Deleting person ID= ",unique_ids[ind])
                        del_idx=np.where(data_taken[:,-3]==unique_ids[ind])[0]
                        print("** index to delete= ",del_idx,"")
                        prev_frame_data=np.delete(prev_frame_data,del_idx,0)
                        person_id_list=np.delete(person_id_list,del_idx,0)
                close_to_door=[]
                person_present=prev_frame_data.shape[0]

        
        
            
        
        #Give Person ID
        #ID Assignment Hungarian Algorithm
        distances=np.zeros((frame_data.shape[0],prev_frame_data.shape[0]))
        ######print("distances shape: ",distances.shape)
        for i in range(frame_data.shape[0]):
            for j in range(prev_frame_data.shape[0]):
                distances[i,j]=np.linalg.norm(frame_data[i,1:4]-prev_frame_data[j,1:4])
            
        row,col=linear_sum_assignment(distances)

        temp=copy.deepcopy(frame_data)


        if frame_data.shape[0]==prev_frame_data.shape[0]:
            frame_data[col,:]=temp[:,:]
            frame_data=np.hstack((frame_data,person_id_list))
        
            #prev_frame_data=copy.deepcopy(frame_data)

            ######print("  changed_data added to all",frame_data[:,1:4])
            
        
        elif frame_data.shape[0]<prev_frame_data.shape[0]: #Sudden Disappearance      

            frame_data=copy.deepcopy(prev_frame_data[:,0:-1])
            frame_data[:,0]=frame
            frame_data[col[0:frame_data.shape[0]],:]=temp[:,:]
            frame_data=np.hstack((frame_data,person_id_list))
            #prev_frame_data=copy.deepcopy(frame_data)


            
        
        
        elif frame_data.shape[0]>prev_frame_data.shape[0]: #Sudden Apperearance
            ######print("SUDDENNNNNN Apperearance")
            temp=copy.deepcopy(frame_data)
            frame_data=temp[row,:]
            temp=copy.deepcopy(frame_data)
            frame_data[col,:]=temp[:,:]
            now_idx=list(range(frame_data.shape[0]))
            del_idx=[x for x in now_idx if x not in col]
            frame_data=np.delete(frame_data,del_idx,0)
            frame_data=np.hstack((frame_data,person_id_list))

        dist_calc=np.linalg.norm(frame_data[:,1:3]-prev_frame_data[:,1:3],axis=1)
        if np.max(dist_calc)>2000:
            print("Frame: ",frame,"  Max dist: ",np.max(dist_calc))
            print("Maybe ghosting")
            frame_data=copy.deepcopy(prev_frame_data)
            frame_data[:,0]=frame
        prev_frame_data=copy.deepcopy(frame_data) #For next frame. data_col_less+1 shape



        frame_data2=np.hstack((frame_data,np.zeros((frame_data.shape[0],2))))
        activ=activity_detection(frame_data)
        ######print("\n\n activ: ",activ,"\n\n")
        frame_data2[:,-2]=activ.reshape(-1)

        
        all_data=np.vstack((all_data,frame_data2))

        ### TRY adding stationary flag for a person who is not moving for 2*fps frames
        
        if frame>2*fps:
            #print("Hello")
            for m in range(person_id_list.shape[0]):
                if frame-entering_frame[m]>2*fps:
                    considered_indices=np.where(all_data[:,0]==frame-2*fps)[0]
                    #print("CONsidered_indices ",considered_indices)
                    considered_indices2=m
                    for n in considered_indices:
                        if all_data[n,-3]==person_id_list[m]:
                            considered_indices2=n
                    
                    ######print("CONsidered_indices2 ",considered_indices2)
                    cons_data=copy.deepcopy(all_data[considered_indices2,1:4])
                    ######print("cons_data ",cons_data[1:4])
                    considered_positions=cons_data
                    current_indices=np.where(all_data[:,0]==frame)[0]
                    for n in current_indices:
                        if all_data[n,-3]==person_id_list[m]:
                            current_indices2=n
                    
                    ######print("CURrent_indices2 ",current_indices2)
                    cur_dat=copy.deepcopy(all_data[current_indices2,1:4])
                    current_positions=cur_dat
                    ######print("for id=",m+1, "dist=", np.linalg.norm(considered_positions-current_positions))
                    if np.linalg.norm(considered_positions-current_positions)<1000: #2 meter
                        frame_data2[m,-1]=1
                        
                        all_data[current_indices2,-1]=1
                        
        
        prev_frame_data=copy.deepcopy(frame_data) #For next frame. Now prev_frame_data.shape[1]=data_col_less+1   
        
        #smoothing
        
        if frame>smooth_window and smooth_window!=0:

            b=[]
            for i in range(frame-smooth_window,frame):
                a=np.where(all_data[:,0]==i)
                
                if a[0].size>0:

                    get=np.array(a[0]).reshape(-1)
                    
                    for j in get:
                        b.append(j)

                
            b=np.array(b).reshape(-1)
            
            if b.size>0:
                considered_data=all_data[b,:].reshape(-1,all_data.shape[1])
                ######print("considered_data ",considered_data.shape)
                
                for i in range(int(np.max(person_id_list)+1)):
                    c=[]
                    c=np.where(considered_data[:,-1]==i)[0]
                    
                    if c!=[]:
                        d1=np.mean(considered_data[c,1:4],axis=0)
                        d2=np.mean(considered_data[c,11:data_col_less],axis=0)


                        e=b[c]
                        all_data[e,1:4]=d1
                        all_data[e,11:14]=d2
        
        #capture1.release_handle()
        #capture2.release_handle()
        #capture3.release_handle()
        #capture4.release_handle()
        capture1.reset()
        capture2.reset()
        capture3.reset()
        capture4.reset()

        
    ######print("FINISHED")
    playback1.close()
    playback2.close()
    playback3.close()
    playback4.close()
# Out:
# enter number
# where to show? 1 for python and 0 for unity and 2 for none
# videos_1 videos_9
# Processing Video=  D:\Video Data\Video Feb 2 Backup\videos_1
# D:\Video Data\Video Feb 2 Backup\videos_1\output1_1.mkv
# frame  0  ,all data shape=  (0, 17)
# Person present  0
# frame  1  ,all data shape=  (0, 17)
# Person present  0
# frame  2  ,all data shape=  (0, 17)
# Person present  0
# frame  3  ,all data shape=  (0, 17)
# Person present  0
# frame  4  ,all data shape=  (0, 17)
# Person present  0
# frame  5  ,all data shape=  (0, 17)
# Person present  0
# frame  6  ,all data shape=  (0, 17)
# Person present  0
# frame  7  ,all data shape=  (0, 17)
# Person present  0
# frame  8  ,all data shape=  (0, 17)
# Person present  0
# frame  9  ,all data shape=  (0, 17)
# Person present  0
# frame  10  ,all data shape=  (0, 17)
# Person present  0
# frame  11  ,all data shape=  (0, 17)
# Person present  0
# frame  12  ,all data shape=  (0, 17)
# Person present  0
# frame  13  ,all data shape=  (0, 17)
# Person present  0
# frame  14  ,all data shape=  (0, 17)
# Person present  0
# frame  15  ,all data shape=  (0, 17)
# Person present  0
# frame  16  ,all data shape=  (0, 17)
# Person present  0
# frame  17  ,all data shape=  (0, 17)
# Person present  0
# frame  18  ,all data shape=  (0, 17)
# Person present  0
# frame  19  ,all data shape=  (0, 17)
# Person present  0
# frame  20  ,all data shape=  (0, 17)
# Person present  0
# frame  21  ,all data shape=  (0, 17)
# Person present  0
# frame  22  ,all data shape=  (0, 17)
# Person present  0
# frame  23  ,all data shape=  (0, 17)
# Person present  0
# frame  24  ,all data shape=  (0, 17)
# Person present  0
# frame  25  ,all data shape=  (0, 17)
# Person present  0
# frame  26  ,all data shape=  (0, 17)
# Person present  0
# frame  27  ,all data shape=  (0, 17)
# Person present  0
# frame  28  ,all data shape=  (0, 17)
# Person present  0
# frame  29  ,all data shape=  (0, 17)
# Person present  0
# frame  30  ,all data shape=  (0, 17)
# Person present  0
# frame  31  ,all data shape=  (0, 17)
# Person present  0
# frame  32  ,all data shape=  (0, 17)
# Person present  0
# frame  33  ,all data shape=  (0, 17)
# Person present  0
# frame  34  ,all data shape=  (0, 17)
# Person present  0
# frame  35  ,all data shape=  (0, 17)
# Person present  0
# frame  36  ,all data shape=  (0, 17)
# Person present  0
# frame  37  ,all data shape=  (0, 17)
# Person present  0
# frame  38  ,all data shape=  (0, 17)
# Person present  0
# frame  39  ,all data shape=  (0, 17)
# Person present  0
# frame  40  ,all data shape=  (0, 17)
# Person present  0
# frame  41  ,all data shape=  (0, 17)
# Person present  0
# frame  42  ,all data shape=  (0, 17)
# Person present  0
# frame  43  ,all data shape=  (0, 17)
# Person present  0
# frame  44  ,all data shape=  (0, 17)
# Person present  0
# frame  45  ,all data shape=  (0, 17)
# Person present  0
# frame  46  ,all data shape=  (0, 17)
# Person present  0
# frame  47  ,all data shape=  (0, 17)
# Person present  0
# frame  48  ,all data shape=  (0, 17)
# Person present  0
# frame  49  ,all data shape=  (0, 17)
# Person present  0
# frame  50  ,all data shape=  (0, 17)
# Person present  0
# frame  51  ,all data shape=  (0, 17)
# Person present  0
# frame  52  ,all data shape=  (0, 17)
# Person present  0
# frame  53  ,all data shape=  (0, 17)
# Person present  0
# frame  54  ,all data shape=  (0, 17)
# Person present  0
# frame  55  ,all data shape=  (0, 17)
# Person present  0
# frame  56  ,all data shape=  (0, 17)
# Person present  0
# frame  57  ,all data shape=  (0, 17)
# Person present  0
# frame  58  ,all data shape=  (0, 17)
# Person present  0
# frame  59  ,all data shape=  (0, 17)
# Person present  0
# frame  60  ,all data shape=  (0, 17)
# Person present  0
# frame  61  ,all data shape=  (0, 17)
# Person present  0
# frame  62  ,all data shape=  (0, 17)
# Person present  0
# frame  63  ,all data shape=  (0, 17)
# Person present  0
# frame  64  ,all data shape=  (0, 17)
# Person present  0
# frame  65  ,all data shape=  (0, 17)
# Person present  0
# frame  66  ,all data shape=  (0, 17)
# Person present  0
# frame  67  ,all data shape=  (0, 17)
# Person present  0
# frame  68  ,all data shape=  (0, 17)
# Person present  0
# frame  69  ,all data shape=  (0, 17)
# Person present  0
# frame  70  ,all data shape=  (0, 17)
# Person present  0
# frame  71  ,all data shape=  (0, 17)
# Person present  0
# frame  72  ,all data shape=  (0, 17)
# Person present  0
# frame  73  ,all data shape=  (0, 17)
# Person present  0
# frame  74  ,all data shape=  (0, 17)
# Person present  0
# frame  75  ,all data shape=  (0, 17)
# Person present  0
# frame  76  ,all data shape=  (0, 17)
# Person present  0
# frame  77  ,all data shape=  (0, 17)
# Person present  0
# frame  78  ,all data shape=  (0, 17)
# Person present  0
# frame  79  ,all data shape=  (0, 17)
# Person present  0
# frame  80  ,all data shape=  (0, 17)
# Person present  0
# frame  81  ,all data shape=  (0, 17)
# Person present  0
# frame  82  ,all data shape=  (0, 17)
# Person present  0
# frame  83  ,all data shape=  (0, 17)
# Person present  0
# frame  84  ,all data shape=  (0, 17)
# Person present  0
# frame  85  ,all data shape=  (0, 17)
# Person present  0
# frame  86  ,all data shape=  (0, 17)
# Person present  0
# frame  87  ,all data shape=  (0, 17)
# Person present  0
# frame  88  ,all data shape=  (0, 17)
# Person present  0
# frame  89  ,all data shape=  (0, 17)
# Person present  0
# frame  90  ,all data shape=  (0, 17)
# Person present  0
# frame  91  ,all data shape=  (0, 17)
# Person present  0
# frame  92  ,all data shape=  (0, 17)
# Person present  0
# frame  93  ,all data shape=  (0, 17)
# Person present  0
# frame  94  ,all data shape=  (0, 17)
# Person present  0
# frame  95  ,all data shape=  (0, 17)
# Person present  0
# frame  96  ,all data shape=  (0, 17)
# Person present  0
# frame  97  ,all data shape=  (0, 17)
# Person present  0
# frame  98  ,all data shape=  (0, 17)
# Person present  0
# frame  99  ,all data shape=  (0, 17)
# Person present  0
# frame  100  ,all data shape=  (0, 17)
# Person present  0
# ****WE HAVE A POSSIBLE ENTRY EVENT
# Person entered
# Nose position:  [   20.15063079 10312.95558871  1464.59276448]
# EXIT PREDICTED AT FRAME  101  WITH ANGLE  173.6316198638342
# frame  101  ,all data shape=  (1, 17)
# Person present  1
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [491.73671817] for ID:  1.0
# frame  102  ,all data shape=  (2, 17)
# Person present  1
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [93.56281313] for ID:  1.0
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [  453.75126886 10135.91115259]
# Temp Exit distance=  469.35269370068545   ID=  1.0
#   Not adding still
# frame  103  ,all data shape=  (3, 17)
# Person present  1
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [75.69015788] for ID:  1.0
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [  530.43526503 10104.63246022]
# Temp Exit distance=  83.81782335186186   ID=  1.0
#   Not adding still
# frame  104  ,all data shape=  (4, 17)
# Person present  1
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [104.50837287] for ID:  1.0
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [  604.43218505 10107.7630704 ]
# Temp Exit distance=  75.06311425295408   ID=  1.0
#   Not adding still
# frame  105  ,all data shape=  (5, 17)
# Person present  1
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [98.71676656] for ID:  1.0
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [  687.39113436 10044.21491561]
# Temp Exit distance=  105.50146050058069   ID=  1.0
#   Not adding still
# frame  106  ,all data shape=  (6, 17)
# Person present  1
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [85.90692638] for ID:  1.0
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [ 755.7474852  9975.02431971]
# Temp Exit distance=  98.26216768273062   ID=  1.0
#   Not adding still
# frame  107  ,all data shape=  (7, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [ 841.44425102 9975.15855117]
# Temp Exit distance=  86.69687095124978   ID=  1.0
#   Not adding still
# frame  108  ,all data shape=  (8, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [ 900.40042981 9933.40124741]
# Temp Exit distance=  73.24613092779481   ID=  1.0
#   Not adding still
# frame  109  ,all data shape=  (9, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [ 967.59170279 9919.0482038 ]
# Temp Exit distance=  69.70718321657992   ID=  1.0
#   Not adding still
# frame  110  ,all data shape=  (10, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [1065.57723539 9942.4565406 ]
# Temp Exit distance=  101.74281528283838   ID=  1.0
#   Not adding still
# frame  111  ,all data shape=  (11, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [1147.92755748 9954.56853002]
# Temp Exit distance=  84.23626515151089   ID=  1.0
#   Not adding still
# frame  112  ,all data shape=  (12, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [1228.98844333 9966.94084868]
# Temp Exit distance=  82.9996431856019   ID=  1.0
#   Not adding still
# frame  113  ,all data shape=  (13, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [1330.2986997  9967.81854176]
# Temp Exit distance=  102.31405821019189   ID=  1.0
#   Not adding still
# frame  114  ,all data shape=  (14, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [1424.67889138 9959.81361561]
# Temp Exit distance=  95.7190552367355   ID=  1.0
#   Not adding still
# frame  115  ,all data shape=  (15, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [1511.72731497 9941.84880249]
# Temp Exit distance=  89.88285864422086   ID=  1.0
#   Not adding still
# frame  116  ,all data shape=  (16, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [1596.18398346 9943.38264269]
# Temp Exit distance=  85.47059558287519   ID=  1.0
#   Not adding still
# frame  117  ,all data shape=  (17, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [1684.1871874  9948.17941176]
# Temp Exit distance=  89.13383513863647   ID=  1.0
#   Not adding still
# frame  118  ,all data shape=  (18, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# Temp data taken=  [1766.33742624 9936.02524897]
# Temp Exit distance=  84.04447853845366   ID=  1.0
#   Not adding still
# frame  119  ,all data shape=  (19, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# frame  120  ,all data shape=  (20, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# frame  121  ,all data shape=  (21, 17)
# Person present  1
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# frame  122  ,all data shape=  (22, 17)
# Person present  1
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [1254.82468895] for ID:  1.0
#   ### New person entered
# ## Enter distance:  1254.824688950612
# ## Entering Nose position:  [  882.26396687 10131.15451694  1501.91522497]
#    Exit flag on and data taken shape= (1, 17)   prev frame data shape=  (1, 17)
# frame  123  ,all data shape=  (24, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# Temp data taken=  [  882.26396687 10131.15451694]
# Temp Exit distance=  10170.49760575032   ID=  2.0
#   Not adding still
# frame  124  ,all data shape=  (26, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# Temp data taken=  [  914.49300269 10098.21158009]
# Temp Exit distance=  47.08630858190751   ID=  2.0
#   Not adding still
# frame  125  ,all data shape=  (28, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# Temp data taken=  [  958.1209402  10103.75334678]
# Temp Exit distance=  44.978495985384924   ID=  2.0
#   Not adding still
# frame  126  ,all data shape=  (30, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# Temp data taken=  [  958.1209402  10103.75334678]
# Temp Exit distance=  1.0   ID=  2.0
#  AAdding to close to door distance=  1.0   ID=  2.0
# frame  127  ,all data shape=  (32, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# Temp data taken=  [ 1179.20373357 10110.62764412]
# Temp Exit distance=  222.18964146065935   ID=  2.0
#   Not adding still
# frame  128  ,all data shape=  (34, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# Temp data taken=  [ 1285.2607673  10121.18950168]
# Temp Exit distance=  107.58164587600886   ID=  2.0
#   Not adding still
# frame  129  ,all data shape=  (36, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# Temp data taken=  [ 1342.8233091  10110.19962267]
# Temp Exit distance=  59.602249613220316   ID=  2.0
#   Not adding still
# frame  130  ,all data shape=  (38, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# Temp data taken=  [ 1437.19337117 10113.80532949]
# Temp Exit distance=  95.43892065946915   ID=  2.0
#   Not adding still
# frame  131  ,all data shape=  (40, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# Temp data taken=  [ 1522.15379461 10117.83327389]
# Temp Exit distance=  86.0558515771944   ID=  2.0
#   Not adding still
# frame  132  ,all data shape=  (42, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# Temp data taken=  [ 1595.57126021 10121.70445458]
# Temp Exit distance=  74.51945521982591   ID=  2.0
#   Not adding still
# frame  133  ,all data shape=  (44, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# Temp data taken=  [ 1665.87761403 10132.82367959]
# Temp Exit distance=  72.1801977548718   ID=  2.0
#   Not adding still
# frame  134  ,all data shape=  (46, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# Temp data taken=  [ 1753.71783716 10112.900814  ]
# Temp Exit distance=  91.07122388818102   ID=  2.0
#   Not adding still
# frame  135  ,all data shape=  (48, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  136  ,all data shape=  (50, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  137  ,all data shape=  (52, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  138  ,all data shape=  (54, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  139  ,all data shape=  (56, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  140  ,all data shape=  (58, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  141  ,all data shape=  (60, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  142  ,all data shape=  (62, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  143  ,all data shape=  (64, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  144  ,all data shape=  (66, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  145  ,all data shape=  (68, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  146  ,all data shape=  (70, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  147  ,all data shape=  (72, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  148  ,all data shape=  (74, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  149  ,all data shape=  (76, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  150  ,all data shape=  (78, 17)
# Person present  2
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  151  ,all data shape=  (80, 17)
# Person present  2
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3064.99885807    0.        ] for ID:  1.0
#   Enter Distances:  [3064.99885807 2231.01982015] for ID:  2.0
#   ### New person entered
# ## Enter distance:  2231.0198201462385
# ## Entering Nose position:  [  845.1427638  10023.58509684  1482.52873116]
#    Exit flag on and data taken shape= (2, 17)   prev frame data shape=  (2, 17)
# frame  152  ,all data shape=  (83, 17)
# Person present  3
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3070.6080831    0.           0.       ] for ID:  1.0
#   Enter Distances:  [3070.6080831  2372.66474665    0.        ] for ID:  2.0
#   Enter Distances:  [3070.6080831  2372.66474665   43.37049688] for ID:  3.0
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [  845.1427638  10023.58509684]
# Temp Exit distance=  10060.15128054045   ID=  3.0
#   Not adding still
# frame  153  ,all data shape=  (86, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [  883.98682998 10010.87071613]
# Temp Exit distance=  41.871958041254   ID=  3.0
#   Not adding still
# frame  154  ,all data shape=  (89, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [ 963.80639395 9993.58043408]
# Temp Exit distance=  82.67078207973454   ID=  3.0
#   Not adding still
# frame  155  ,all data shape=  (92, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [ 989.22301836 9962.92821924]
# Temp Exit distance=  40.81912945972232   ID=  3.0
#   Not adding still
# frame  156  ,all data shape=  (95, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1036.57064407 9939.71458965]
# Temp Exit distance=  53.732061015002465   ID=  3.0
#   Not adding still
# frame  157  ,all data shape=  (98, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1101.97212497 9895.18965242]
# Temp Exit distance=  80.11904788681956   ID=  3.0
#   Not adding still
# frame  158  ,all data shape=  (101, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1112.36549747 9821.84655034]
# Temp Exit distance=  75.07585852020158   ID=  3.0
#   Not adding still
# frame  159  ,all data shape=  (104, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1164.83042588 9762.80494728]
# Temp Exit distance=  79.98404652038718   ID=  3.0
#   Not adding still
# frame  160  ,all data shape=  (107, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1218.47659535 9728.36619367]
# Temp Exit distance=  64.74903331672446   ID=  3.0
#   Not adding still
# frame  161  ,all data shape=  (110, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1257.55939259 9682.98398067]
# Temp Exit distance=  60.89165465677632   ID=  3.0
#   Not adding still
# frame  162  ,all data shape=  (113, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1310.48549294 9614.54829189]
# Temp Exit distance=  87.51367288983036   ID=  3.0
#   Not adding still
# frame  163  ,all data shape=  (116, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1328.80506894 9553.67537172]
# Temp Exit distance=  64.56979844929663   ID=  3.0
#   Not adding still
# frame  164  ,all data shape=  (119, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1386.41296367 9529.15539001]
# Temp Exit distance=  63.609097089120915   ID=  3.0
#   Not adding still
# frame  165  ,all data shape=  (122, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1418.41892942 9475.45853262]
# Temp Exit distance=  63.51187357125725   ID=  3.0
#   Not adding still
# frame  166  ,all data shape=  (125, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1456.08174606 9447.16676782]
# Temp Exit distance=  48.10532573994446   ID=  3.0
#   Not adding still
# frame  167  ,all data shape=  (128, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1478.7889621  9424.83986505]
# Temp Exit distance=  32.84506629070505   ID=  3.0
#   Not adding still
# frame  168  ,all data shape=  (131, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1504.49975779 9381.50640914]
# Temp Exit distance=  51.38683773560665   ID=  3.0
#   Not adding still
# frame  169  ,all data shape=  (134, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1528.92507783 9380.17906077]
# Temp Exit distance=  25.46135958388126   ID=  3.0
#   Not adding still
# frame  170  ,all data shape=  (137, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1561.44152904 9345.30379327]
# Temp Exit distance=  48.68232253251894   ID=  3.0
#   Not adding still
# frame  171  ,all data shape=  (140, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1581.11947638 9300.71024496]
# Temp Exit distance=  49.7422420809764   ID=  3.0
#   Not adding still
# frame  172  ,all data shape=  (143, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1618.66463975 9261.24513891]
# Temp Exit distance=  55.471404308166534   ID=  3.0
#   Not adding still
# frame  173  ,all data shape=  (146, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1669.43779084 9212.93188875]
# Temp Exit distance=  71.08625409586135   ID=  3.0
#   Not adding still
# frame  174  ,all data shape=  (149, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1727.40205298 9184.96834674]
# Temp Exit distance=  65.356937209651   ID=  3.0
#   Not adding still
# frame  175  ,all data shape=  (152, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1711.17793843 9129.35058455]
# Temp Exit distance=  58.935803816089404   ID=  3.0
#   Not adding still
# frame  176  ,all data shape=  (155, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1768.84805468 9086.9918875 ]
# Temp Exit distance=  72.55488470036944   ID=  3.0
#   Not adding still
# frame  177  ,all data shape=  (158, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1773.1180753  9078.26270216]
# Temp Exit distance=  10.717600152593228   ID=  3.0
#   Not adding still
# frame  178  ,all data shape=  (161, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1799.6565061  9046.58282876]
# Temp Exit distance=  42.32677931298329   ID=  3.0
#   Not adding still
# frame  179  ,all data shape=  (164, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1797.53332497 9025.36772914]
# Temp Exit distance=  22.321077601745035   ID=  3.0
#   Not adding still
# frame  180  ,all data shape=  (167, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  181  ,all data shape=  (170, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  182  ,all data shape=  (173, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1761.88073603 8985.59615473]
# Temp Exit distance=  52.83208279671107   ID=  3.0
#   Not adding still
# frame  183  ,all data shape=  (176, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  184  ,all data shape=  (179, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  185  ,all data shape=  (182, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1774.67327469 8993.31343352]
# Temp Exit distance=  41.46594871308592   ID=  3.0
#   Not adding still
# frame  186  ,all data shape=  (185, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  187  ,all data shape=  (188, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  188  ,all data shape=  (191, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  189  ,all data shape=  (194, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  190  ,all data shape=  (197, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  191  ,all data shape=  (200, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# Temp data taken=  [1799.47124386 8941.62641136]
# Temp Exit distance=  23.874738452952844   ID=  3.0
#   Not adding still
# frame  192  ,all data shape=  (203, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  193  ,all data shape=  (206, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  194  ,all data shape=  (209, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  195  ,all data shape=  (212, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  196  ,all data shape=  (215, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  197  ,all data shape=  (218, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  198  ,all data shape=  (221, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  199  ,all data shape=  (224, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  200  ,all data shape=  (227, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  201  ,all data shape=  (230, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  202  ,all data shape=  (233, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  203  ,all data shape=  (236, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  204  ,all data shape=  (239, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  205  ,all data shape=  (242, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  206  ,all data shape=  (245, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  207  ,all data shape=  (248, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  208  ,all data shape=  (251, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  209  ,all data shape=  (254, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  210  ,all data shape=  (257, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  211  ,all data shape=  (260, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  212  ,all data shape=  (263, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  213  ,all data shape=  (266, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  214  ,all data shape=  (269, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  215  ,all data shape=  (272, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  216  ,all data shape=  (275, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  217  ,all data shape=  (278, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  218  ,all data shape=  (281, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  219  ,all data shape=  (284, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  220  ,all data shape=  (287, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  221  ,all data shape=  (290, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  222  ,all data shape=  (293, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  223  ,all data shape=  (296, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  224  ,all data shape=  (299, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  225  ,all data shape=  (302, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  226  ,all data shape=  (305, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  227  ,all data shape=  (308, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  228  ,all data shape=  (311, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  229  ,all data shape=  (314, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  230  ,all data shape=  (317, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  231  ,all data shape=  (320, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  232  ,all data shape=  (323, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  233  ,all data shape=  (326, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  234  ,all data shape=  (329, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  235  ,all data shape=  (332, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  236  ,all data shape=  (335, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  237  ,all data shape=  (338, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  238  ,all data shape=  (341, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  239  ,all data shape=  (344, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  240  ,all data shape=  (347, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  241  ,all data shape=  (350, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  242  ,all data shape=  (353, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  243  ,all data shape=  (356, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  244  ,all data shape=  (359, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  245  ,all data shape=  (362, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  246  ,all data shape=  (365, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  247  ,all data shape=  (368, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  248  ,all data shape=  (371, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  249  ,all data shape=  (374, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  250  ,all data shape=  (377, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# frame  251  ,all data shape=  (380, 17)
# Person present  3
#    Exit flag on and data taken shape= (3, 17)   prev frame data shape=  (3, 17)
# *****Exit frame counter reached
# ****close to door count= 1   ID=  2.0
# frame  252  ,all data shape=  (383, 17)
# Person present  3
# frame  253  ,all data shape=  (386, 17)
# Person present  3
# frame  254  ,all data shape=  (389, 17)
# Person present  3
# frame  255  ,all data shape=  (392, 17)
# Person present  3
# frame  256  ,all data shape=  (395, 17)
# Person present  3
# frame  257  ,all data shape=  (398, 17)
# Person present  3
# frame  258  ,all data shape=  (401, 17)
# Person present  3
# frame  259  ,all data shape=  (404, 17)
# Person present  3
# frame  260  ,all data shape=  (407, 17)
# Person present  3
# frame  261  ,all data shape=  (410, 17)
# Person present  3
# frame  262  ,all data shape=  (413, 17)
# Person present  3
# frame  263  ,all data shape=  (416, 17)
# Person present  3
# frame  264  ,all data shape=  (419, 17)
# Person present  3
# frame  265  ,all data shape=  (422, 17)
# Person present  3
# frame  266  ,all data shape=  (425, 17)
# Person present  3
# frame  267  ,all data shape=  (428, 17)
# Person present  3
# frame  268  ,all data shape=  (431, 17)
# Person present  3
# frame  269  ,all data shape=  (434, 17)
# Person present  3
# frame  270  ,all data shape=  (437, 17)
# Person present  3
# frame  271  ,all data shape=  (440, 17)
# Person present  3
# frame  272  ,all data shape=  (443, 17)
# Person present  3
# frame  273  ,all data shape=  (446, 17)
# Person present  3
# frame  274  ,all data shape=  (449, 17)
# Person present  3
# frame  275  ,all data shape=  (452, 17)
# Person present  3
# frame  276  ,all data shape=  (455, 17)
# Person present  3
# frame  277  ,all data shape=  (458, 17)
# Person present  3
# frame  278  ,all data shape=  (461, 17)
# Person present  3
# frame  279  ,all data shape=  (464, 17)
# Person present  3
# frame  280  ,all data shape=  (467, 17)
# Person present  3
# frame  281  ,all data shape=  (470, 17)
# Person present  3
# frame  282  ,all data shape=  (473, 17)
# Person present  3
# frame  283  ,all data shape=  (476, 17)
# Person present  3
# frame  284  ,all data shape=  (479, 17)
# Person present  3
# frame  285  ,all data shape=  (482, 17)
# Person present  3
# frame  286  ,all data shape=  (485, 17)
# Person present  3
# frame  287  ,all data shape=  (488, 17)
# Person present  3
# frame  288  ,all data shape=  (491, 17)
# Person present  3
# frame  289  ,all data shape=  (494, 17)
# Person present  3
# frame  290  ,all data shape=  (497, 17)
# Person present  3
# frame  291  ,all data shape=  (500, 17)
# Person present  3
# frame  292  ,all data shape=  (503, 17)
# Person present  3
# frame  293  ,all data shape=  (506, 17)
# Person present  3
# frame  294  ,all data shape=  (509, 17)
# Person present  3
# frame  295  ,all data shape=  (512, 17)
# Person present  3
# frame  296  ,all data shape=  (515, 17)
# Person present  3
# frame  297  ,all data shape=  (518, 17)
# Person present  3
# frame  298  ,all data shape=  (521, 17)
# Person present  3
# frame  299  ,all data shape=  (524, 17)
# Person present  3
# frame  300  ,all data shape=  (527, 17)
# Person present  3
# frame  301  ,all data shape=  (530, 17)
# Person present  3
# frame  302  ,all data shape=  (533, 17)
# Person present  3
# frame  303  ,all data shape=  (536, 17)
# Person present  3
# frame  304  ,all data shape=  (539, 17)
# Person present  3
# frame  305  ,all data shape=  (542, 17)
# Person present  3
# frame  306  ,all data shape=  (545, 17)
# Person present  3
# frame  307  ,all data shape=  (548, 17)
# Person present  3
# frame  308  ,all data shape=  (551, 17)
# Person present  3
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3459.26585032    0.            0.        ] for ID:  1.0
#   Enter Distances:  [3459.26585032 5217.66333388    0.        ] for ID:  2.0
#   Enter Distances:  [3459.26585032 5217.66333388 2772.42819341] for ID:  3.0
#   ### New person entered
# ## Enter distance:  2772.428193406415
# ## Entering Nose position:  [  402.95507168 10250.91489206  1571.39497415]
# frame  309  ,all data shape=  (555, 17)
# Person present  4
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3403.99089057    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [3403.99089057 5173.81333819    0.            0.        ] for ID:  2.0
#   Enter Distances:  [3403.99089057 5173.81333819 2762.25982835    0.        ] for ID:  3.0
#   Enter Distances:  [3403.99089057 5173.81333819 2762.25982835   86.68909966] for ID:  4.0
# frame  310  ,all data shape=  (559, 17)
# Person present  4
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3654.35086838    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [3654.35086838 5426.0202666     0.            0.        ] for ID:  2.0
#   Enter Distances:  [3654.35086838 5426.0202666  2992.06520975    0.        ] for ID:  3.0
#   Enter Distances:  [3654.35086838 5426.0202666  2992.06520975  289.32162035] for ID:  4.0
# EXIT PREDICTED AT FRAME  311  WITH ANGLE  168.74781404431582
# frame  311  ,all data shape=  (563, 17)
# Person present  4
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3503.24596404    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [3503.24596404 5235.1452287     0.            0.        ] for ID:  2.0
#   Enter Distances:  [3503.24596404 5235.1452287  2782.33297313    0.        ] for ID:  3.0
#   Enter Distances:  [3503.24596404 5235.1452287  2782.33297313  239.35329536] for ID:  4.0
# EXIT PREDICTED AT FRAME  312  WITH ANGLE  132.03482662131927
# frame  312  ,all data shape=  (567, 17)
# Person present  4
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3210.76642072    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [3210.76642072 4987.16694179    0.            0.        ] for ID:  2.0
#   Enter Distances:  [3210.76642072 4987.16694179 2551.26251633    0.        ] for ID:  3.0
#   Enter Distances:  [3210.76642072 4987.16694179 2551.26251633  279.91070005] for ID:  4.0
# frame  313  ,all data shape=  (571, 17)
# Person present  4
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [3199.59885927    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [3199.59885927 4965.9310106     0.            0.        ] for ID:  2.0
#   Enter Distances:  [3199.59885927 4965.9310106  2524.1307491     0.        ] for ID:  3.0
#   Enter Distances:  [3199.59885927 4965.9310106  2524.1307491    96.62297863] for ID:  4.0
# EXIT PREDICTED AT FRAME  314  WITH ANGLE  123.71850555528142
# frame  314  ,all data shape=  (575, 17)
# Person present  4
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [2971.04881255    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [2971.04881255 4788.0551584     0.            0.        ] for ID:  2.0
#   Enter Distances:  [2971.04881255 4788.0551584  2370.02178044    0.        ] for ID:  3.0
#   Enter Distances:  [2971.04881255 4788.0551584  2370.02178044  250.22190152] for ID:  4.0
# frame  315  ,all data shape=  (579, 17)
# Person present  4
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [2930.09504852    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [2930.09504852 4727.1932117     0.            0.        ] for ID:  2.0
#   Enter Distances:  [2930.09504852 4727.1932117  2308.11168828    0.        ] for ID:  3.0
#   Enter Distances:  [2930.09504852 4727.1932117  2308.11168828   63.4428877 ] for ID:  4.0
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [ 728.1927156  9963.15963872]
# Temp Exit distance=  237.9979336461744   ID=  4.0
#   Not adding still
# frame  316  ,all data shape=  (583, 17)
# Person present  4
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [2832.33716543    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [2832.33716543 4640.6268244     0.            0.        ] for ID:  2.0
#   Enter Distances:  [2832.33716543 4640.6268244  2225.21265995    0.        ] for ID:  3.0
#   Enter Distances:  [2832.33716543 4640.6268244  2225.21265995   85.11756575] for ID:  4.0
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [ 761.08241127 9911.5067329 ]
# Temp Exit distance=  62.23524117263066   ID=  4.0
#   Not adding still
# frame  317  ,all data shape=  (587, 17)
# Person present  4
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [2764.83960811    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [2764.83960811 4564.73949587    0.            0.        ] for ID:  2.0
#   Enter Distances:  [2764.83960811 4564.73949587 2151.83237983    0.        ] for ID:  3.0
#   Enter Distances:  [2764.83960811 4564.73949587 2151.83237983   78.13449942] for ID:  4.0
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [ 827.82267579 9858.83528055]
# Temp Exit distance=  86.02084921741387   ID=  4.0
#   Not adding still
# frame  318  ,all data shape=  (591, 17)
# Person present  4
# ****WE HAVE A POSSIBLE ENTRY EVENT
#
#   Enter Distances:  [2683.10301743    0.            0.            0.        ] for ID:  1.0
#   Enter Distances:  [2683.10301743 4515.93265988    0.            0.        ] for ID:  2.0
#   Enter Distances:  [2683.10301743 4515.93265988 2099.36464327    0.        ] for ID:  3.0
#   Enter Distances:  [2683.10301743 4515.93265988 2099.36464327   53.94441584] for ID:  4.0
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [ 869.62438184 9796.03694854]
# Temp Exit distance=  76.43880388218834   ID=  4.0
#   Not adding still
# frame  319  ,all data shape=  (595, 17)
# Person present  4
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [ 896.26762564 9749.38108434]
# Temp Exit distance=  54.727386910778854   ID=  4.0
#   Not adding still
# frame  320  ,all data shape=  (599, 17)
# Person present  4
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [ 941.18105574 9694.86581273]
# Temp Exit distance=  71.63378116511556   ID=  4.0
#   Not adding still
# frame  321  ,all data shape=  (603, 17)
# Person present  4
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [ 968.86767042 9639.73339581]
# Temp Exit distance=  62.69385729709421   ID=  4.0
#   Not adding still
# frame  322  ,all data shape=  (607, 17)
# Person present  4
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [ 987.59358194 9574.0363688 ]
# Temp Exit distance=  69.3136817964901   ID=  4.0
#   Not adding still
# frame  323  ,all data shape=  (611, 17)
# Person present  4
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [ 996.92881336 9535.70729237]
# Temp Exit distance=  40.44952021566525   ID=  4.0
#   Not adding still
# frame  324  ,all data shape=  (615, 17)
# Person present  4
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1023.18597242 9479.67973447]
# Temp Exit distance=  62.875080985680675   ID=  4.0
#   Not adding still
# frame  325  ,all data shape=  (619, 17)
# Person present  4
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1082.83255379 9404.95131963]
# Temp Exit distance=  96.61407141878186   ID=  4.0
#   Not adding still
# frame  326  ,all data shape=  (623, 17)
# Person present  4
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1095.33837399 9339.87738003]
# Temp Exit distance=  67.26472027277063   ID=  4.0
#   Not adding still
# frame  327  ,all data shape=  (627, 17)
# Person present  4
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1178.86602735 9280.69364836]
# Temp Exit distance=  103.36983428562057   ID=  4.0
#   Not adding still
# frame  328  ,all data shape=  (631, 17)
# Person present  4
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1230.00904073 9225.48994777]
# Temp Exit distance=  76.2532814918841   ID=  4.0
#   Not adding still
# frame  329  ,all data shape=  (635, 17)
# Person present  4
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1195.98140086 9171.65371428]
# Temp Exit distance=  64.68846293841662   ID=  4.0
#   Not adding still
# frame  330  ,all data shape=  (639, 17)
# Person present  4
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1153.30192313 9149.26334506]
# Temp Exit distance=  49.19612486915102   ID=  4.0
#   Not adding still
# frame  331  ,all data shape=  (643, 17)
# Person present  4
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1100.22242706 9093.63393849]
# Temp Exit distance=  77.88994588883757   ID=  4.0
#   Not adding still
# frame  332  ,all data shape=  (647, 17)
# Person present  4
#    Exit flag on and data taken shape= (4, 17)   prev frame data shape=  (4, 17)
# Temp data taken=  [1109.32027047 8992.67838855]
# ...
# frame  1114  ,all data shape=  (6851, 17)
# Person present  4
# frame  1115  ,all data shape=  (6855, 17)
# Person present  4
# frame  1116  ,all data shape=  (6859, 17)
# Person present  4
# frame  1117  ,all data shape=  (6863, 17)
# Person present  4
# frame  1118  ,all data shape=  (6867, 17)
# Person present  4
# frame  1119  ,all data shape=  (6871, 17)
# Person present  4
# frame  1120  ,all data shape=  (6875, 17)
# Person present  4
# frame  1121  ,all data shape=  (6879, 17)
# Person present  4
# frame  1122  ,all data shape=  (6883, 17)
# Person present  4
# frame  1123  ,all data shape=  (6887, 17)
# Person present  4
# frame  1124  ,all data shape=  (6891, 17)
# Person present  4
# frame  1125  ,all data shape=  (6895, 17)
# Person present  4
# frame  1126  ,all data shape=  (6899, 17)
# Person present  4
# frame  1127  ,all data shape=  (6903, 17)
# Person present  4
# frame  1128  ,all data shape=  (6907, 17)
# Person present  4
# frame  1129  ,all data shape=  (6911, 17)
# Person present  4
# frame  1130  ,all data shape=  (6915, 17)
# Person present  4
# frame  1131  ,all data shape=  (6919, 17)
# Person present  4
# frame  1132  ,all data shape=  (6923, 17)
# Person present  4
# frame  1133  ,all data shape=  (6927, 17)
# Person present  4
# frame  1134  ,all data shape=  (6931, 17)
# Person present  4
# frame  1135  ,all data shape=  (6935, 17)
# Person present  4
# frame  1136  ,all data shape=  (6939, 17)
# Person present  4
# frame  1137  ,all data shape=  (6943, 17)
# Person present  4
# frame  1138  ,all data shape=  (6947, 17)
# Person present  4
# frame  1139  ,all data shape=  (6951, 17)
# Person present  4
# frame  1140  ,all data shape=  (6955, 17)
# Person present  4
# frame  1141  ,all data shape=  (6959, 17)
# Person present  4
# frame  1142  ,all data shape=  (6963, 17)
# Person present  4
# frame  1143  ,all data shape=  (6967, 17)
# Person present  4
# frame  1144  ,all data shape=  (6971, 17)
# Person present  4
# frame  1145  ,all data shape=  (6975, 17)
# Person present  4
# frame  1146  ,all data shape=  (6979, 17)
# Person present  4
# frame  1147  ,all data shape=  (6983, 17)
# Person present  4
# frame  1148  ,all data shape=  (6987, 17)
# Person present  4
# frame  1149  ,all data shape=  (6991, 17)
# Person present  4
# frame  1150  ,all data shape=  (6995, 17)
# Person present  4
# frame  1151  ,all data shape=  (6999, 17)
# Person present  4
# frame  1152  ,all data shape=  (7003, 17)
# Person present  4
# frame  1153  ,all data shape=  (7007, 17)
# Person present  4
# frame  1154  ,all data shape=  (7011, 17)
# Person present  4
# frame  1155  ,all data shape=  (7015, 17)
# Person present  4
# frame  1156  ,all data shape=  (7019, 17)
# Person present  4
# frame  1157  ,all data shape=  (7023, 17)
# Person present  4
# frame  1158  ,all data shape=  (7027, 17)
# Person present  4
# frame  1159  ,all data shape=  (7031, 17)
# Person present  4
# frame  1160  ,all data shape=  (7035, 17)
# Person present  4
# frame  1161  ,all data shape=  (7039, 17)
# Person present  4
# frame  1162  ,all data shape=  (7043, 17)
# Person present  4
# frame  1163  ,all data shape=  (7047, 17)
# Person present  4
# frame  1164  ,all data shape=  (7051, 17)
# Person present  4
# frame  1165  ,all data shape=  (7055, 17)
# Person present  4
# frame  1166  ,all data shape=  (7059, 17)
# Person present  4
# frame  1167  ,all data shape=  (7063, 17)
# Person present  4
# frame  1168  ,all data shape=  (7067, 17)
# Person present  4
# frame  1169  ,all data shape=  (7071, 17)
# Person present  4
# frame  1170  ,all data shape=  (7075, 17)
# Person present  4
# frame  1171  ,all data shape=  (7079, 17)
# Person present  4
# frame  1172  ,all data shape=  (7083, 17)
# Person present  4
# frame  1173  ,all data shape=  (7087, 17)
# Person present  4
# frame  1174  ,all data shape=  (7091, 17)
# Person present  4
# frame  1175  ,all data shape=  (7095, 17)
# Person present  4
# frame  1176  ,all data shape=  (7099, 17)
# Person present  4
# frame  1177  ,all data shape=  (7103, 17)
# Person present  4
# frame  1178  ,all data shape=  (7107, 17)
# Person present  4
# frame  1179  ,all data shape=  (7111, 17)
# Person present  4
# frame  1180  ,all data shape=  (7115, 17)
# Person present  4
# frame  1181  ,all data shape=  (7119, 17)
# Person present  4
# frame  1182  ,all data shape=  (7123, 17)
# Person present  4
# frame  1183  ,all data shape=  (7127, 17)
# Person present  4
# frame  1184  ,all data shape=  (7131, 17)
# Person present  4
# frame  1185  ,all data shape=  (7135, 17)
# Person present  4
# frame  1186  ,all data shape=  (7139, 17)
# Person present  4
# frame  1187  ,all data shape=  (7143, 17)
# Person present  4
# frame  1188  ,all data shape=  (7147, 17)
# Person present  4
# frame  1189  ,all data shape=  (7151, 17)
# Person present  4
# frame  1190  ,all data shape=  (7155, 17)
# Person present  4
# frame  1191  ,all data shape=  (7159, 17)
# Person present  4
# frame  1192  ,all data shape=  (7163, 17)
# Person present  4
# frame  1193  ,all data shape=  (7167, 17)
# Person present  4
# frame  1194  ,all data shape=  (7171, 17)
# Person present  4
# frame  1195  ,all data shape=  (7175, 17)
# Person present  4
# frame  1196  ,all data shape=  (7179, 17)
# Person present  4
# frame  1197  ,all data shape=  (7183, 17)
# Person present  4
# frame  1198  ,all data shape=  (7187, 17)
# Person present  4
# frame  1199  ,all data shape=  (7191, 17)
# Person present  4
# frame  1200  ,all data shape=  (7195, 17)
# Person present  4
#  Take index FROM  300
#      saving
# [1, 1, 1, 1]
# frame  301  ,all data shape=  (3608, 17)
# Person present  4
# frame  302  ,all data shape=  (3612, 17)
# Person present  4
# frame  303  ,all data shape=  (3616, 17)
# Person present  4
# frame  304  ,all data shape=  (3620, 17)
# Person present  4
# frame  305  ,all data shape=  (3624, 17)
# Person present  4
# frame  306  ,all data shape=  (3628, 17)
# Person present  4
# frame  307  ,all data shape=  (3632, 17)
# Person present  4
# frame  308  ,all data shape=  (3636, 17)
# Person present  4
# frame  309  ,all data shape=  (3640, 17)
# Person present  4
# frame  310  ,all data shape=  (3644, 17)
# Person present  4
# frame  311  ,all data shape=  (3648, 17)
# Person present  4
# frame  312  ,all data shape=  (3652, 17)
# Person present  4
# frame  313  ,all data shape=  (3656, 17)
# Person present  4
# frame  314  ,all data shape=  (3660, 17)
# Person present  4
# frame  315  ,all data shape=  (3664, 17)
# Person present  4
# frame  316  ,all data shape=  (3668, 17)
# Person present  4
# frame  317  ,all data shape=  (3672, 17)
# Person present  4
# frame  318  ,all data shape=  (3676, 17)
# Person present  4
# frame  319  ,all data shape=  (3680, 17)
# Person present  4
# frame  320  ,all data shape=  (3684, 17)
# Person present  4
# frame  321  ,all data shape=  (3688, 17)
# Person present  4
# frame  322  ,all data shape=  (3692, 17)
# Person present  4
# frame  323  ,all data shape=  (3696, 17)
# Person present  4
# frame  324  ,all data shape=  (3700, 17)
# Person present  4
# frame  325  ,all data shape=  (3704, 17)
# Person present  4
# frame  326  ,all data shape=  (3708, 17)
# Person present  4
# frame  327  ,all data shape=  (3712, 17)
# Person present  4
# frame  328  ,all data shape=  (3716, 17)
# Person present  4
# frame  329  ,all data shape=  (3720, 17)
# Person present  4
# frame  330  ,all data shape=  (3724, 17)
# Person present  4
# frame  331  ,all data shape=  (3728, 17)
# Person present  4
# frame  332  ,all data shape=  (3732, 17)
# Person present  4
# frame  333  ,all data shape=  (3736, 17)
# Person present  4
# frame  334  ,all data shape=  (3740, 17)
# Person present  4
# frame  335  ,all data shape=  (3744, 17)
# Person present  4
# frame  336  ,all data shape=  (3748, 17)
# Person present  4
# frame  337  ,all data shape=  (3752, 17)
# Person present  4
# frame  338  ,all data shape=  (3756, 17)
# Person present  4
# frame  339  ,all data shape=  (3760, 17)
# Person present  4
# frame  340  ,all data shape=  (3764, 17)
# Person present  4
# frame  341  ,all data shape=  (3768, 17)
# Person present  4
# frame  342  ,all data shape=  (3772, 17)
# Person present  4
# frame  343  ,all data shape=  (3776, 17)
# Person present  4
# frame  344  ,all data shape=  (3780, 17)
# Person present  4
# frame  345  ,all data shape=  (3784, 17)
# Person present  4
# frame  346  ,all data shape=  (3788, 17)
# Person present  4
# frame  347  ,all data shape=  (3792, 17)
# Person present  4
# frame  348  ,all data shape=  (3796, 17)
# Person present  4
# frame  349  ,all data shape=  (3800, 17)
# Person present  4
# frame  350  ,all data shape=  (3804, 17)
# Person present  4
# frame  351  ,all data shape=  (3808, 17)
# Person present  4
# frame  352  ,all data shape=  (3812, 17)
# Person present  4
# frame  353  ,all data shape=  (3816, 17)
# Person present  4
# frame  354  ,all data shape=  (3820, 17)
# Person present  4
# frame  355  ,all data shape=  (3824, 17)
# Person present  4
# frame  356  ,all data shape=  (3828, 17)
# Person present  4
# frame  357  ,all data shape=  (3832, 17)
# Person present  4
# frame  358  ,all data shape=  (3836, 17)
# Person present  4
# frame  359  ,all data shape=  (3840, 17)
# Person present  4
# frame  360  ,all data shape=  (3844, 17)
# Person present  4
# frame  361  ,all data shape=  (3848, 17)
# Person present  4
# frame  362  ,all data shape=  (3852, 17)
# Person present  4
# frame  363  ,all data shape=  (3856, 17)
# Person present  4
# frame  364  ,all data shape=  (3860, 17)
# Person present  4
# frame  365  ,all data shape=  (3864, 17)
# Person present  4
# frame  366  ,all data shape=  (3868, 17)
# Person present  4
# frame  367  ,all data shape=  (3872, 17)
# Person present  4
# frame  368  ,all data shape=  (3876, 17)
# Person present  4
# frame  369  ,all data shape=  (3880, 17)
# Person present  4
# frame  370  ,all data shape=  (3884, 17)
# Person present  4
# frame  371  ,all data shape=  (3888, 17)
# Person present  4
# frame  372  ,all data shape=  (3892, 17)
# Person present  4
# frame  373  ,all data shape=  (3896, 17)
# Person present  4
# frame  374  ,all data shape=  (3900, 17)
# Person present  4
# frame  375  ,all data shape=  (3904, 17)
# Person present  4
# frame  376  ,all data shape=  (3908, 17)
# Person present  4
# frame  377  ,all data shape=  (3912, 17)
# Person present  4
# frame  378  ,all data shape=  (3916, 17)
# Person present  4
# frame  379  ,all data shape=  (3920, 17)
# Person present  4
# frame  380  ,all data shape=  (3924, 17)
# Person present  4
# frame  381  ,all data shape=  (3928, 17)
# Person present  4
# frame  382  ,all data shape=  (3932, 17)
# Person present  4
# frame  383  ,all data shape=  (3936, 17)
# Person present  4
# frame  384  ,all data shape=  (3940, 17)
# Person present  4
# frame  385  ,all data shape=  (3944, 17)
# Person present  4
# frame  386  ,all data shape=  (3948, 17)
# Person present  4
# frame  387  ,all data shape=  (3952, 17)
# Person present  4
# frame  388  ,all data shape=  (3956, 17)
# Person present  4
# frame  389  ,all data shape=  (3960, 17)
# Person present  4
# frame  390  ,all data shape=  (3964, 17)
# Person present  4
# frame  391  ,all data shape=  (3968, 17)
# Person present  4
# frame  392  ,all data shape=  (3972, 17)
# Person present  4
# frame  393  ,all data shape=  (3976, 17)
# Person present  4
# frame  394  ,all data shape=  (3980, 17)
# Person present  4
# frame  395  ,all data shape=  (3984, 17)
# Person present  4
# frame  396  ,all data shape=  (3988, 17)
# Person present  4
# frame  397  ,all data shape=  (3992, 17)
# Person present  4
# frame  398  ,all data shape=  (3996, 17)
# Person present  4
# frame  399  ,all data shape=  (4000, 17)
# Person present  4
# frame  400  ,all data shape=  (4004, 17)
# Person present  4
# frame  401  ,all data shape=  (4008, 17)
# Person present  4
# frame  402  ,all data shape=  (4012, 17)
# Person present  4
# frame  403  ,all data shape=  (4016, 17)
# Person present  4
# frame  404  ,all data shape=  (4020, 17)
# Person present  4
# frame  405  ,all data shape=  (4024, 17)
# Person present  4
# frame  406  ,all data shape=  (4028, 17)
# Person present  4
# frame  407  ,all data shape=  (4032, 17)
# Person present  4
# frame  408  ,all data shape=  (4036, 17)
# Person present  4
# frame  409  ,all data shape=  (4040, 17)
# Person present  4
# frame  410  ,all data shape=  (4044, 17)
# Person present  4
# frame  411  ,all data shape=  (4048, 17)
# Person present  4
# frame  412  ,all data shape=  (4052, 17)
# Person present  4
# frame  413  ,all data shape=  (4056, 17)
# Person present  4
# frame  414  ,all data shape=  (4060, 17)
# Person present  4
# frame  415  ,all data shape=  (4064, 17)
# Person present  4
# frame  416  ,all data shape=  (4068, 17)
# Person present  4
# frame  417  ,all data shape=  (4072, 17)
# Person present  4
# frame  418  ,all data shape=  (4076, 17)
# Person present  4
# frame  419  ,all data shape=  (4080, 17)
# Person present  4
# frame  420  ,all data shape=  (4084, 17)
# Person present  4
# frame  421  ,all data shape=  (4088, 17)
# Person present  4
# frame  422  ,all data shape=  (4092, 17)
# Person present  4
# frame  423  ,all data shape=  (4096, 17)
# Person present  4
# frame  424  ,all data shape=  (4100, 17)
# Person present  4
# frame  425  ,all data shape=  (4104, 17)
# Person present  4
# frame  426  ,all data shape=  (4108, 17)
# Person present  4
# frame  427  ,all data shape=  (4112, 17)
# Person present  4
# frame  428  ,all data shape=  (4116, 17)
# Person present  4
# frame  429  ,all data shape=  (4120, 17)
# Person present  4
# frame  430  ,all data shape=  (4124, 17)
# Person present  4
# frame  431  ,all data shape=  (4128, 17)
# Person present  4
# frame  432  ,all data shape=  (4132, 17)
# Person present  4
# frame  433  ,all data shape=  (4136, 17)
# Person present  4
# frame  434  ,all data shape=  (4140, 17)
# Person present  4
# frame  435  ,all data shape=  (4144, 17)
# Person present  4
# frame  436  ,all data shape=  (4148, 17)
# Person present  4
# frame  437  ,all data shape=  (4152, 17)
# Person present  4
# frame  438  ,all data shape=  (4156, 17)
# Person present  4
# frame  439  ,all data shape=  (4160, 17)
# Person present  4
# frame  440  ,all data shape=  (4164, 17)
# Person present  4
# frame  441  ,all data shape=  (4168, 17)
# Person present  4
# frame  442  ,all data shape=  (4172, 17)
# Person present  4
# frame  443  ,all data shape=  (4176, 17)
# Person present  4
# frame  444  ,all data shape=  (4180, 17)
# Person present  4
# frame  445  ,all data shape=  (4184, 17)
# Person present  4
# frame  446  ,all data shape=  (4188, 17)
# Person present  4
# frame  447  ,all data shape=  (4192, 17)
# Person present  4
# frame  448  ,all data shape=  (4196, 17)
# Person present  4
# frame  449  ,all data shape=  (4200, 17)
# Person present  4
# frame  450  ,all data shape=  (4204, 17)
# Person present  4
# frame  451  ,all data shape=  (4208, 17)
# Person present  4
# frame  452  ,all data shape=  (4212, 17)
# Person present  4
# frame  453  ,all data shape=  (4216, 17)
# Person present  4
# frame  454  ,all data shape=  (4220, 17)
# Person present  4
# frame  455  ,all data shape=  (4224, 17)
# Person present  4
# frame  456  ,all data shape=  (4228, 17)
# Person present  4
# frame  457  ,all data shape=  (4232, 17)
# Person present  4
# frame  458  ,all data shape=  (4236, 17)
# Person present  4
# frame  459  ,all data shape=  (4240, 17)
# Person present  4
# frame  460  ,all data shape=  (4244, 17)
# Person present  4
# frame  461  ,all data shape=  (4248, 17)
# Person present  4
# frame  462  ,all data shape=  (4252, 17)
# Person present  4
# frame  463  ,all data shape=  (4256, 17)
# Person present  4
# frame  464  ,all data shape=  (4260, 17)
# Person present  4
# frame  465  ,all data shape=  (4264, 17)
# Person present  4
# frame  466  ,all data shape=  (4268, 17)
# Person present  4
# frame  467  ,all data shape=  (4272, 17)
# Person present  4
# frame  468  ,all data shape=  (4276, 17)
# Person present  4
# frame  469  ,all data shape=  (4280, 17)
# Person present  4
# frame  470  ,all data shape=  (4284, 17)
# Person present  4
# frame  471  ,all data shape=  (4288, 17)
# Person present  4
# frame  472  ,all data shape=  (4292, 17)
# Person present  4
# frame  473  ,all data shape=  (4296, 17)
# Person present  4
# frame  474  ,all data shape=  (4300, 17)
# Person present  4
# frame  475  ,all data shape=  (4304, 17)
# Person present  4
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
